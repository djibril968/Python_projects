# %%
#we start by importing out libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
import numpy as np
np.float_ = np.float64

# %%
import prophet

# %%
#Now we import our data dict
data_dict = pd.read_excel('./Fin_data_01.xlsx', sheet_name= 'dictionary')
data_dict
# Out:
#                                                  Year  \
# 0                                        Month - name
# 1                                     Month -sequence
# 2                                                Date
# 3                                       Business Line
# 4                                           Amount, $
# 5                                    Expense subgroup
# 6                              Income / Expense Group
# 7                                   Income or expense
# 8                                                 NaN
# 9                                                 NaN
# 10  Example of calculations within an Income State...
# 11               Revenue  (sum of all revenue groups)
# 12               COGS (sum of all costs of good sold)
# 13                      Gross Profit (Revenue - COGS)
# 14                OPEX (sum of all operating expense)
# 15                         EBIT (Gross profit - OPEX)
# 16                                   Interest and Tax
# 17               Net profit (EBIT - Interest and Tax)
#
#                               Year of revenue/expense
# 0                            Month of revenue/expense
# 1       Month of revenue/expense, expressed as number
# 2   Date of revenue/expense, expressed as the last...
# 3   Business line generating revenue / expense (Sp...
# 4                    Revenue or expense amount in USD
# 5   Additional subgroups categorizing expenses ass...
# 6   Subcategory of revenue / expense. Revenue subc...
# 7   Column indicating if associated amount is reve...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                             100000
# 12                                              20000
# 13                                              80000
# 14                                              30000
# 15                                              50000
# 16                                              15000
# 17                                              35000

# %% [markdown]
# We start by describing our dataset with summary statistics

# %%
Fin_data = pd.read_excel('./Fin_data_01.xlsx')
Fin_data
# Out:
#      Year Month - name  Month -sequence       Date  \
# 0    2023      January                1 2023-01-31
# 1    2023      January                1 2023-01-31
# 2    2023      January                1 2023-01-31
# 3    2023      January                1 2023-01-31
# 4    2023      January                1 2023-01-31
# ..    ...          ...              ...        ...
# 575  2023     December                1 2023-12-31
# 576  2023     December                1 2023-12-31
# 577  2023     December                1 2023-12-31
# 578  2023     December                1 2023-12-31
# 579  2023     December                1 2023-12-31
#
#                        Business Line  Amount, $ Expense subgroup  \
# 0    Nutrition and Food Supplements      153000              NaN
# 1    Nutrition and Food Supplements       27000              NaN
# 2    Nutrition and Food Supplements        6000              NaN
# 3    Nutrition and Food Supplements      -15000             Rent
# 4    Nutrition and Food Supplements       -9000        Equipment
# ..                               ...        ...              ...
# 575                       Sportswear      -4000        Packaging
# 576                       Sportswear      -7000         Shipping
# 577                       Sportswear      -9000            Sales
# 578                       Sportswear    -110000            Labor
# 579                       Sportswear      -7000            Other
#
#                   Revenue / Expense Group Revenue or expense
# 0                                   Sales            Revenue
# 1    Consulting and professional services            Revenue
# 2                            Other income            Revenue
# 3                                    Opex            Expense
# 4                                    Opex            Expense
# ..                                    ...                ...
# 575                                  COGS            Expense
# 576                                  COGS            Expense
# 577                                  COGS            Expense
# 578                                  COGS            Expense
# 579                                  COGS            Expense
#
# [580 rows x 9 columns]

# %%
Fin_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580 entries, 0 to 579
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     580 non-null    int64
#  1   Month - name             580 non-null    object
#  2   Month -sequence          580 non-null    int64
#  3   Date                     580 non-null    datetime64[ns]
#  4   Business Line            580 non-null    object
#  5   Amount, $                580 non-null    int64
#  6   Expense subgroup         468 non-null    object
#  7   Revenue / Expense Group  580 non-null    object
#  8   Revenue or expense       580 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 40.9+ KB

# %%
Fin_data.describe()
# Out:
#          Year  Month -sequence                           Date      Amount, $
# count   580.0            580.0                            580     580.000000
# mean   2023.0              1.0  2023-07-15 01:49:14.482758656    7438.137931
# min    2023.0              1.0            2023-01-31 00:00:00 -234000.000000
# 25%    2023.0              1.0            2023-03-31 00:00:00  -30000.000000
# 50%    2023.0              1.0            2023-06-30 00:00:00  -10800.000000
# 75%    2023.0              1.0            2023-09-30 00:00:00   -1800.000000
# max    2023.0              1.0            2023-12-31 00:00:00  750000.000000
# std       0.0              0.0                            NaN  118699.587071

# %%
Fin_data.columns
# Out:
# Index(['Year', 'Month - name', 'Month -sequence', 'Date', 'Business Line',
#        'Amount, $', 'Expense subgroup', 'Revenue / Expense Group',
#        'Revenue or expense'],
#       dtype='object')

# %% [markdown]
# Now we move on to expanding our date columns for effective drill down

# %%
#Now we shall rename columns

Fin_data.rename(columns= {'Month - name': 'Month_name'}, inplace= True)

# %%
Fin_data.rename(columns= {'Month -sequence' : 'Month_sequence', 'Amount, $': 'Amount', 'Expense subgroup' : 'Expense_subgroup', 'Revenue or expense' : 'Rev_or_exp'
                          , 'Revenue / Expense Group' : 'Rev_exp_group','Business Line': 'Biz_line' }, inplace= True)

# %%
#now we extract week from date 

def week_of_mon(col):
    first_day_of_mon = col.replace(day = 1)
    dom = col.day
    adjusted_dom = first_day_of_mon.weekday() + dom
    return int(np.ceil(adjusted_dom)/7)

Fin_data['week'] = Fin_data['Date'].apply(week_of_mon)

# %%
Fin_data['week'] = 'week' + ' ' + Fin_data['week'].astype(str)
Fin_data['Quarter'] = Fin_data['Date'].dt.quarter
Fin_data['Quarter'] = 'qtr ' + Fin_data['Quarter'].astype(str)
Fin_data['mon_no'] = Fin_data['Date'].dt.month

Fin_data['Month_name'] = Fin_data['Month_name'].str[:3]

Fin_data
# Out:
#      Year Month_name  Month_sequence       Date  \
# 0    2023        Jan               1 2023-01-31
# 1    2023        Jan               1 2023-01-31
# 2    2023        Jan               1 2023-01-31
# 3    2023        Jan               1 2023-01-31
# 4    2023        Jan               1 2023-01-31
# ..    ...        ...             ...        ...
# 575  2023        Dec               1 2023-12-31
# 576  2023        Dec               1 2023-12-31
# 577  2023        Dec               1 2023-12-31
# 578  2023        Dec               1 2023-12-31
# 579  2023        Dec               1 2023-12-31
#
#                             Biz_line  Amount Expense_subgroup  \
# 0    Nutrition and Food Supplements   153000              NaN
# 1    Nutrition and Food Supplements    27000              NaN
# 2    Nutrition and Food Supplements     6000              NaN
# 3    Nutrition and Food Supplements   -15000             Rent
# 4    Nutrition and Food Supplements    -9000        Equipment
# ..                               ...     ...              ...
# 575                       Sportswear   -4000        Packaging
# 576                       Sportswear   -7000         Shipping
# 577                       Sportswear   -9000            Sales
# 578                       Sportswear -110000            Labor
# 579                       Sportswear   -7000            Other
#
#                             Rev_exp_group Rev_or_exp    week Quarter  mon_no
# 0                                   Sales    Revenue  week 5   qtr 1       1
# 1    Consulting and professional services    Revenue  week 5   qtr 1       1
# 2                            Other income    Revenue  week 5   qtr 1       1
# 3                                    Opex    Expense  week 5   qtr 1       1
# 4                                    Opex    Expense  week 5   qtr 1       1
# ..                                    ...        ...     ...     ...     ...
# 575                                  COGS    Expense  week 5   qtr 4      12
# 576                                  COGS    Expense  week 5   qtr 4      12
# 577                                  COGS    Expense  week 5   qtr 4      12
# 578                                  COGS    Expense  week 5   qtr 4      12
# 579                                  COGS    Expense  week 5   qtr 4      12
#
# [580 rows x 12 columns]

# %%
Fin_data['mon_day'] = Fin_data['Date'].dt.day

Fin_data['week_day'] = Fin_data['Date'].dt.day_name()

# %%
Fin_data['mon_day'].dtype
# Out:
# dtype('int32')

# %%
Fin_data['Amount'] = Fin_data['Amount'].abs()
Fin_data
# Out:
#      Year Month_name  Month_sequence       Date  \
# 0    2023        Jan               1 2023-01-31
# 1    2023        Jan               1 2023-01-31
# 2    2023        Jan               1 2023-01-31
# 3    2023        Jan               1 2023-01-31
# 4    2023        Jan               1 2023-01-31
# ..    ...        ...             ...        ...
# 575  2023        Dec               1 2023-12-31
# 576  2023        Dec               1 2023-12-31
# 577  2023        Dec               1 2023-12-31
# 578  2023        Dec               1 2023-12-31
# 579  2023        Dec               1 2023-12-31
#
#                             Biz_line  Amount Expense_subgroup  \
# 0    Nutrition and Food Supplements   153000              NaN
# 1    Nutrition and Food Supplements    27000              NaN
# 2    Nutrition and Food Supplements     6000              NaN
# 3    Nutrition and Food Supplements    15000             Rent
# 4    Nutrition and Food Supplements     9000        Equipment
# ..                               ...     ...              ...
# 575                       Sportswear    4000        Packaging
# 576                       Sportswear    7000         Shipping
# 577                       Sportswear    9000            Sales
# 578                       Sportswear  110000            Labor
# 579                       Sportswear    7000            Other
#
#                             Rev_exp_group Rev_or_exp    week Quarter  mon_no  \
# 0                                   Sales    Revenue  week 5   qtr 1       1
# 1    Consulting and professional services    Revenue  week 5   qtr 1       1
# 2                            Other income    Revenue  week 5   qtr 1       1
# 3                                    Opex    Expense  week 5   qtr 1       1
# 4                                    Opex    Expense  week 5   qtr 1       1
# ..                                    ...        ...     ...     ...     ...
# 575                                  COGS    Expense  week 5   qtr 4      12
# 576                                  COGS    Expense  week 5   qtr 4      12
# 577                                  COGS    Expense  week 5   qtr 4      12
# 578                                  COGS    Expense  week 5   qtr 4      12
# 579                                  COGS    Expense  week 5   qtr 4      12
#
#      mon_day week_day
# 0         31  Tuesday
# 1         31  Tuesday
# 2         31  Tuesday
# 3         31  Tuesday
# 4         31  Tuesday
# ..       ...      ...
# 575       31   Sunday
# 576       31   Sunday
# 577       31   Sunday
# 578       31   Sunday
# 579       31   Sunday
#
# [580 rows x 14 columns]

# %% [markdown]
# We move on to exploring individual columns

# %%
Fin_data['Expense_subgroup'].value_counts()
# Out:
# Expense_subgroup
# Other               72
# Rent                36
# Marketing           36
# Equipment           36
# Payroll             36
# R&D                 36
# Materials           36
# Packaging           36
# Shipping            36
# Sales               36
# Labor               36
# Interest and tax    36
# Name: count, dtype: int64

# %%
#here we pull data for expenses only

rev_only = Fin_data.query('Rev_or_exp == "Revenue"')
total_rev = rev_only['Amount'].sum()
total_rev
# Out:
# np.int64(17559820)

# %%
#now we look into total_expense

exp_only = Fin_data.query('Rev_or_exp == "Expense"')
exp_only
total_exp = exp_only['Amount'].sum()
total_exp
# Out:
# np.int64(13245700)

# %%
Fin_data['Rev_exp_group'].value_counts()
# Out:
# Rev_exp_group
# COGS                                    216
# Opex                                    216
# Other income                             40
# Sales                                    36
# Consulting and professional services     36
# Interest and tax                         36
# Name: count, dtype: int64

# %%
Fin_data['Rev_or_exp'].value_counts()
# Out:
# Rev_or_exp
# Expense    468
# Revenue    112
# Name: count, dtype: int64

# %%
Fin_data.query('Rev_exp_group == "COGS"').head()
# Out:
#     Year Month_name  Month_sequence       Date  \
# 9   2023        Jan               1 2023-01-31
# 10  2023        Jan               1 2023-01-31
# 11  2023        Jan               1 2023-01-31
# 12  2023        Jan               1 2023-01-31
# 13  2023        Jan               1 2023-01-31
#
#                            Biz_line  Amount Expense_subgroup Rev_exp_group  \
# 9   Nutrition and Food Supplements    20000        Materials          COGS
# 10  Nutrition and Food Supplements     1200        Packaging          COGS
# 11  Nutrition and Food Supplements     2700         Shipping          COGS
# 12  Nutrition and Food Supplements     3000            Sales          COGS
# 13  Nutrition and Food Supplements    65000            Labor          COGS
#
#    Rev_or_exp    week Quarter  mon_no  mon_day week_day
# 9     Expense  week 5   qtr 1       1       31  Tuesday
# 10    Expense  week 5   qtr 1       1       31  Tuesday
# 11    Expense  week 5   qtr 1       1       31  Tuesday
# 12    Expense  week 5   qtr 1       1       31  Tuesday
# 13    Expense  week 5   qtr 1       1       31  Tuesday

# %%
Fin_data[['Biz_line', 'Expense_subgroup', 'Amount', 'Rev_exp_group']]
# Out:
#                             Biz_line Expense_subgroup  Amount  \
# 0    Nutrition and Food Supplements               NaN  153000
# 1    Nutrition and Food Supplements               NaN   27000
# 2    Nutrition and Food Supplements               NaN    6000
# 3    Nutrition and Food Supplements              Rent   15000
# 4    Nutrition and Food Supplements         Equipment    9000
# ..                               ...              ...     ...
# 575                       Sportswear        Packaging    4000
# 576                       Sportswear         Shipping    7000
# 577                       Sportswear            Sales    9000
# 578                       Sportswear            Labor  110000
# 579                       Sportswear            Other    7000
#
#                             Rev_exp_group
# 0                                   Sales
# 1    Consulting and professional services
# 2                            Other income
# 3                                    Opex
# 4                                    Opex
# ..                                    ...
# 575                                  COGS
# 576                                  COGS
# 577                                  COGS
# 578                                  COGS
# 579                                  COGS
#
# [580 rows x 4 columns]

# %%
#Fin_data.loc[Fin_data['Rev_exp_group'] == 'Consulting and professional services',['Biz_line', 'Expense_subgroup', 'Amount', 'Rev_exp_group']]

# %%
Fin_data.loc[Fin_data['Rev_exp_group'] == 'COGS',['Biz_line', 'Expense_subgroup', 'Amount', 'Rev_exp_group']].head()
# Out:
#                            Biz_line Expense_subgroup  Amount Rev_exp_group
# 9   Nutrition and Food Supplements         Materials   20000          COGS
# 10  Nutrition and Food Supplements         Packaging    1200          COGS
# 11  Nutrition and Food Supplements          Shipping    2700          COGS
# 12  Nutrition and Food Supplements             Sales    3000          COGS
# 13  Nutrition and Food Supplements             Labor   65000          COGS

# %%
Fin_data.loc[Fin_data['Rev_exp_group'] == 'Opex',['Biz_line', 'Expense_subgroup', 'Amount', 'Rev_exp_group']].head()
# Out:
#                           Biz_line Expense_subgroup  Amount Rev_exp_group
# 3  Nutrition and Food Supplements              Rent   15000          Opex
# 4  Nutrition and Food Supplements         Equipment    9000          Opex
# 5  Nutrition and Food Supplements         Marketing   30000          Opex
# 6  Nutrition and Food Supplements           Payroll   40000          Opex
# 7  Nutrition and Food Supplements               R&D   30000          Opex

# %% [markdown]
# Exploratory Data Analysis

# %%
#Total revenue, expense and gross profit

df_rev_exp = ['tot_rev', 'tot_exp', 'net_profit']
df_rev_exp = pd.DataFrame(df_rev_exp)

#tot_rev =Fin_data[Fin_data['Rev_or_exp'] == 'Revenue', ['Amount'].sum()]
tot_rev_01 = Fin_data.groupby('Rev_or_exp')['Amount'].sum().reset_index(name= 'Amount')
tot_rev_01
# Out:
#   Rev_or_exp    Amount
# 0    Expense  13245700
# 1    Revenue  17559820

# %%
#sns.barplot(x= 'Rev_or_exp', y= 'Amount', data= tot_rev_01 )

# %% [markdown]
# Rev and expense across biz lines

# %%
#tot_revenue acros biz line

tot_rev_data_ext = Fin_data.loc[Fin_data['Rev_or_exp']== 'Revenue', ['Biz_line', 'Amount', 'Rev_exp_group', 'Rev_or_exp']]


pd.set_option('display.max_rows', 200)
tot_rev_biz_line = tot_rev_data_ext.groupby('Biz_line')['Amount'].sum().reset_index(name = 'tot_rev').sort_values('tot_rev', ascending = False)
tot_rev_biz_line
# Out:
#                           Biz_line  tot_rev
# 1                 Sports equipment  8908500
# 2                       Sportswear  6807700
# 0  Nutrition and Food Supplements   1843620

# %%
sns.barplot(x= 'Biz_line', y= 'tot_rev', hue= 'tot_rev', data = tot_rev_biz_line)
# Out:
# <Axes: xlabel='Biz_line', ylabel='tot_rev'>

# %%
#df = Fin_data.loc[Fin_data['Rev_or_exp']== 'Revenue', ['Biz_line', 'Amount', 'Rev_exp_group', 'Rev_or_exp']]
#df.head()

# %%
#total_expense across biz lines

#first we extract the data needed for expenses

tot_exp_data_ext = Fin_data.loc[Fin_data['Rev_or_exp']=='Expense', ['Biz_line', 'Amount', 'Expense_subgroup','Rev_exp_group', 'Rev_or_exp']]


pd.set_option('display.max_rows', 470)
tot_exp_biz_line = tot_exp_data_ext.groupby('Biz_line')['Amount'].sum().reset_index(name= 'tot_exp').sort_values('tot_exp', ascending = False)
tot_exp_biz_line
# Out:
#                           Biz_line  tot_exp
# 1                 Sports equipment  6618300
# 2                       Sportswear  4070900
# 0  Nutrition and Food Supplements   2556500

# %%
sns.set_color_codes("pastel")
sns.barplot(x= 'tot_exp', y= 'Biz_line', color= 'b', data= tot_exp_biz_line )
# Out:
# <Axes: xlabel='tot_exp', ylabel='Biz_line'>

# %%
#tot exp across various sub_groups

sub_group_tot_exp = tot_exp_data_ext.groupby('Expense_subgroup')['Amount'].sum().reset_index(name = 'tot_exp').sort_values('tot_exp', ascending = False)
sub_group_tot_exp
# Out:
#     Expense_subgroup  tot_exp
# 2              Labor  4492000
# 7            Payroll  1790000
# 0          Equipment  1333000
# 4          Materials  1065000
# 3          Marketing  1055000
# 1   Interest and tax   929400
# 9               Rent   745000
# 8                R&D   540000
# 10             Sales   447000
# 5              Other   405500
# 11          Shipping   345600
# 6          Packaging    98200

# %%
data_01 = sub_group_tot_exp.sort_values('tot_exp', ascending= True)
sns.barplot(x= 'tot_exp', y= 'Expense_subgroup', hue = 'tot_exp', data= data_01)
# Out:
# <Axes: xlabel='tot_exp', ylabel='Expense_subgroup'>

# %%
#total rev across various Rev_exp_group

tot_rev_group = tot_rev_data_ext.groupby('Rev_exp_group')['Amount'].sum().reset_index(name= 'tot_rev').sort_values('tot_rev', ascending= False)
tot_rev_group
# Out:
#                           Rev_exp_group   tot_rev
# 2                                 Sales  13776630
# 0  Consulting and professional services   2817000
# 1                          Other income    966190

# %%
sns.barplot(x= 'Rev_exp_group', y= 'tot_rev', hue= 'tot_rev',  data= tot_rev_group)
# Out:
# <Axes: xlabel='Rev_exp_group', ylabel='tot_rev'>

# %%
#total expenses across various Rev_exp_group

tot_exp_group = tot_exp_data_ext.groupby('Rev_exp_group')['Amount'].sum().reset_index(name= 'tot_exp').sort_values('tot_exp', ascending = True)
tot_exp_group
# Out:
#       Rev_exp_group  tot_exp
# 1  Interest and tax   929400
# 2              Opex  5604800
# 0              COGS  6711500

# %%
sns.violinplot(x=tot_exp_group['Rev_exp_group'], color= 'gold' )
# Out:
# <Axes: xlabel='Rev_exp_group'>

# %%
Fin_data.groupby('Rev_exp_group')['Amount'].sum().reset_index(name='total').sort_values('total', ascending= False)
# Out:
#                           Rev_exp_group     total
# 5                                 Sales  13776630
# 0                                  COGS   6711500
# 3                                  Opex   5604800
# 1  Consulting and professional services   2817000
# 4                          Other income    966190
# 2                      Interest and tax    929400

# %% [markdown]
# Overall trend analysis for biz line, expense_subgroup, rev_exp_subgroup and Rev_or_exp_group

# %% [markdown]
# Monthly Trends

# %%
#extracting required data for trend overview

trend_rev_extract = Fin_data.loc[Fin_data['Rev_or_exp'] == 'Revenue', ['Month_name', 'mon_no', 'Quarter', 'week', 'week_day', 'Biz_line', 'Rev_exp_group', 'Rev_or_exp', 'Amount' ]]

trend_exp_extract = Fin_data.loc[Fin_data['Rev_or_exp'] == 'Expense', ['Month_name', 'mon_no','Quarter', 'week', 'week_day', 'Biz_line', 'Rev_exp_group', 'Expense_subgroup', 'Rev_or_exp', 'Amount' ]]

# %%
trend_exp_extract
# Out:
#     Month_name  mon_no Quarter    week   week_day  \
# 3          Jan       1   qtr 1  week 5    Tuesday
# 4          Jan       1   qtr 1  week 5    Tuesday
# 5          Jan       1   qtr 1  week 5    Tuesday
# 6          Jan       1   qtr 1  week 5    Tuesday
# 90         Jun       6   qtr 2  week 4     Friday
# 91         Jun       6   qtr 2  week 4     Friday
# 92         Jun       6   qtr 2  week 4     Friday
# 93         Jun       6   qtr 2  week 4     Friday
# 94         Jun       6   qtr 2  week 4     Friday
# 95         Jun       6   qtr 2  week 4     Friday
# 96         Jun       6   qtr 2  week 4     Friday
# 97         Jun       6   qtr 2  week 4     Friday
# 98         Jun       6   qtr 2  week 4     Friday
# 99         Jun       6   qtr 2  week 4     Friday
# 100        Jun       6   qtr 2  week 4     Friday
# 101        Jun       6   qtr 2  week 4     Friday
# 102        Jul       7   qtr 3  week 5     Monday
# 105        Jul       7   qtr 3  week 5     Monday
# 106        Jul       7   qtr 3  week 5     Monday
# 107        Jul       7   qtr 3  week 5     Monday
# 108        Jul       7   qtr 3  week 5     Monday
# 109        Jul       7   qtr 3  week 5     Monday
# 110        Jul       7   qtr 3  week 5     Monday
# 111        Jul       7   qtr 3  week 5     Monday
# 112        Jul       7   qtr 3  week 5     Monday
# 113        Jul       7   qtr 3  week 5     Monday
# 114        Jul       7   qtr 3  week 5     Monday
# 115        Jul       7   qtr 3  week 5     Monday
# 116        Jul       7   qtr 3  week 5     Monday
# 117        Aug       8   qtr 3  week 4   Thursday
# 120        Aug       8   qtr 3  week 4   Thursday
# 121        Aug       8   qtr 3  week 4   Thursday
# 122        Aug       8   qtr 3  week 4   Thursday
# 123        Aug       8   qtr 3  week 4   Thursday
# 124        Aug       8   qtr 3  week 4   Thursday
# 125        Aug       8   qtr 3  week 4   Thursday
# 126        Aug       8   qtr 3  week 4   Thursday
# 127        Aug       8   qtr 3  week 4   Thursday
# 128        Aug       8   qtr 3  week 4   Thursday
# 129        Aug       8   qtr 3  week 4   Thursday
# 130        Aug       8   qtr 3  week 4   Thursday
# 131        Aug       8   qtr 3  week 4   Thursday
# 132        Sep       9   qtr 3  week 4   Saturday
# 135        Sep       9   qtr 3  week 4   Saturday
# 136        Sep       9   qtr 3  week 4   Saturday
# 137        Sep       9   qtr 3  week 4   Saturday
# 138        Sep       9   qtr 3  week 4   Saturday
# 139        Sep       9   qtr 3  week 4   Saturday
# 140        Sep       9   qtr 3  week 4   Saturday
# 141        Sep       9   qtr 3  week 4   Saturday
# 142        Sep       9   qtr 3  week 4   Saturday
# 143        Sep       9   qtr 3  week 4   Saturday
# 144        Sep       9   qtr 3  week 4   Saturday
# 145        Sep       9   qtr 3  week 4   Saturday
# 146        Sep       9   qtr 3  week 4   Saturday
# 147        Oct      10   qtr 4  week 5    Tuesday
# 150        Oct      10   qtr 4  week 5    Tuesday
# 151        Oct      10   qtr 4  week 5    Tuesday
# 152        Oct      10   qtr 4  week 5    Tuesday
# 153        Oct      10   qtr 4  week 5    Tuesday
# 154        Oct      10   qtr 4  week 5    Tuesday
# 155        Oct      10   qtr 4  week 5    Tuesday
# 156        Oct      10   qtr 4  week 5    Tuesday
# 157        Oct      10   qtr 4  week 5    Tuesday
# 158        Oct      10   qtr 4  week 5    Tuesday
# 365                 Sports equipment              Opex             Other
# 366                 Sports equipment              COGS         Materials
# 367                 Sports equipment              COGS         Packaging
# 368                 Sports equipment              COGS          Shipping
# 369                 Sports equipment              COGS             Sales
# 370                 Sports equipment              COGS             Labor
# 371                 Sports equipment              COGS             Other
# 372                 Sports equipment  Interest and tax  Interest and tax
# 375                 Sports equipment              Opex              Rent
# 376                 Sports equipment              Opex         Equipment
# 377                 Sports equipment              Opex         Marketing
# 378                 Sports equipment              Opex           Payroll
# ...
# 504                       Sportswear              COGS          Shipping
# 505                       Sportswear              COGS             Sales
# 506                       Sportswear              COGS             Labor
# 507                       Sportswear              COGS             Other
# 510                       Sportswear  Interest and tax  Interest and tax
# 514                       Sportswear              Opex              Rent
# 515                       Sportswear              Opex         Equipment
# 516                       Sportswear              Opex         Marketing
# 517                       Sportswear              Opex           Payroll
# 518                       Sportswear              Opex               R&D
# 519                       Sportswear              Opex             Other
# 520                       Sportswear              COGS         Materials
# 521                       Sportswear              COGS         Packaging
# 522                       Sportswear              COGS          Shipping
# 523                       Sportswear              COGS             Sales
# 524                       Sportswear              COGS             Labor
# 525                       Sportswear              COGS             Other
# 528                       Sportswear  Interest and tax  Interest and tax
# 532                       Sportswear              Opex              Rent
# 533                       Sportswear              Opex         Equipment
# 534                       Sportswear              Opex         Marketing
# 535                       Sportswear              Opex           Payroll
# 536                       Sportswear              Opex               R&D
# 537                       Sportswear              Opex             Other
# 538                       Sportswear              COGS         Materials
# 539                       Sportswear              COGS         Packaging
# 540                       Sportswear              COGS          Shipping
# 541                       Sportswear              COGS             Sales
# 542                       Sportswear              COGS             Labor
# 543                       Sportswear              COGS             Other
# 546                       Sportswear  Interest and tax  Interest and tax
# 550                       Sportswear              Opex              Rent
# 551                       Sportswear              Opex         Equipment
# 552                       Sportswear              Opex         Marketing
# 553                       Sportswear              Opex           Payroll
# 554                       Sportswear              Opex               R&D
# 555                       Sportswear              Opex             Other
# 556                       Sportswear              COGS         Materials
# 557                       Sportswear              COGS         Packaging
# 558                       Sportswear              COGS          Shipping
# 559                       Sportswear              COGS             Sales
# 560                       Sportswear              COGS             Labor
# 561                       Sportswear              COGS             Other
# 564                       Sportswear  Interest and tax  Interest and tax
# 568                       Sportswear              Opex              Rent
# 569                       Sportswear              Opex         Equipment
# 570                       Sportswear              Opex         Marketing
# 571                       Sportswear              Opex           Payroll
# 572                       Sportswear              Opex               R&D
# 573                       Sportswear              Opex             Other
# 574                       Sportswear              COGS         Materials
# 575                       Sportswear              COGS         Packaging
# 576                       Sportswear              COGS          Shipping
# 577                       Sportswear              COGS             Sales
# 578                       Sportswear              COGS             Labor
# 579                       Sportswear              COGS             Other
#
#     Rev_or_exp  Amount
# 3      Expense   15000
# 4      Expense    9000
# 5      Expense   30000
# 6      Expense   40000
# 7      Expense   30000
# 8      Expense    1500
# 9      Expense   20000
# 10     Expense    1200
# 11     Expense    2700
# 12     Expense    3000
# 13     Expense   65000
# 14     Expense    2100
# 15     Expense   12000
# 21     Expense   15000
# 22     Expense    9000
# 23     Expense   30000
# 24     Expense   40000
# 25     Expense   30000
# 26     Expense    1500
# 27     Expense   20000
# 28     Expense    1200
# 29     Expense    2400
# 30     Expense    3000
# 31     Expense   65000
# 32     Expense    1800
# 33     Expense   12000
# 39     Expense   15000
# 40     Expense    9000
# 41     Expense   15000
# 42     Expense   40000
# 43     Expense   30000
# 44     Expense     900
# 45     Expense   20000
# 46     Expense     600
# 47     Expense    1500
# 48     Expense    2100
# 49     Expense   65000
# 50     Expense    1500
# 51     Expense   12000
# 57     Expense   15000
# 58     Expense    9000
# 59     Expense   15000
# 60     Expense   40000
# 61     Expense   30000
# 62     Expense     900
# 63     Expense   20000
# 64     Expense     600
# 65     Expense    1500
# 66     Expense    1800
# 67     Expense   65000
# 68     Expense    3000
# 69     Expense   12000
# 72     Expense   12000
# 75     Expense   15000
# 76     Expense   11400
# 77     Expense   30000
# 78     Expense   40000
# 79     Expense   30000
# 80     Expense    1200
# 81     Expense   20000
# 82     Expense    1200
# 83     Expense    2400
# 84     Expense    2700
# 85     Expense   65000
# 86     Expense    3000
# 87     Expense   12000
# 90     Expense   15000
# 91     Expense   11400
# 92     Expense   30000
# 93     Expense   40000
# 94     Expense   30000
# 95     Expense     900
# 96     Expense   20000
# 97     Expense     900
# 98     Expense    2700
# 99     Expense    2400
# 100    Expense   65000
# 101    Expense    3000
# 102    Expense   12000
# 105    Expense   15000
# 106    Expense   11400
# 107    Expense   20000
# 108    Expense   40000
# 109    Expense   30000
# 110    Expense     600
# 111    Expense   20000
# 112    Expense     600
# 113    Expense    1500
# 114    Expense    1800
# 115    Expense   50000
# 116    Expense    3000
# 117    Expense   12000
# 120    Expense   15000
# 121    Expense   11400
# 122    Expense   15000
# 123    Expense   40000
# 124    Expense   30000
# 125    Expense     600
# 126    Expense   20000
# 127    Expense     600
# 128    Expense    1500
# 129    Expense    1800
# 130    Expense   50000
# 131    Expense    3000
# 132    Expense   12000
# 135    Expense   15000
# 136    Expense   11400
# 137    Expense   15000
# 138    Expense   32000
# 139    Expense   30000
# 140    Expense     900
# 141    Expense   20000
# 142    Expense     600
# 143    Expense    1200
# 144    Expense    1800
# 145    Expense   50000
# 146    Expense    2100
# 147    Expense   12000
# 150    Expense   15000
# 151    Expense   12000
# 152    Expense   15000
# 153    Expense   32000
# 154    Expense   30000
# 155    Expense     600
# 156    Expense   20000
# 157    Expense     600
# 158    Expense    1200
# 159    Expense    1800
# 160    Expense   50000
# 161    Expense    2100
# 162    Expense   12000
# 165    Expense   15000
# 166    Expense   12000
# 167    Expense   20000
# 168    Expense   32000
# 169    Expense   30000
# 170    Expense    1200
# 171    Expense   20000
# 172    Expense     900
# 173    Expense     900
# 174    Expense    2100
# 175    Expense   50000
# 176    Expense    1800
# 177    Expense   12000
# 180    Expense   15000
# 181    Expense   12000
# 182    Expense   30000
# 183    Expense   32000
# 184    Expense   30000
# 185    Expense    2400
# 186    Expense   20000
# 187    Expense    1200
# 188    Expense    2100
# 189    Expense    2700
# 190    Expense   50000
# 191    Expense    2100
# 194    Expense   18000
# 195    Expense   54000
# 196    Expense   50000
# 197    Expense   60000
# 198    Expense   10000
# 199    Expense   14400
# 200    Expense   50000
# 201    Expense    6000
# 202    Expense  130000
# 203    Expense   30000
# 204    Expense  180000
# 205    Expense   12600
# 207    Expense   49000
# 210    Expense   27000
# 211    Expense   54000
# 212    Expense   50000
# 213    Expense   60000
# 214    Expense   10000
# 215    Expense    9000
# 216    Expense   20000
# 217    Expense    5000
# 218    Expense   12000
# 219    Expense   25000
# 220    Expense  180000
# 221    Expense   12600
# 223    Expense   48500
# 226    Expense   27000
# 227    Expense   54000
# 228    Expense   30000
# 229    Expense   60000
# 230    Expense   10000
# 231    Expense    5400
# 232    Expense   54000
# 233    Expense    3600
# 234    Expense    9000
# 235    Expense   12600
# 236    Expense  180000
# 237    Expense   12600
# 239    Expense   37000
# 242    Expense   27000
# 243    Expense   54000
# 244    Expense   30000
# 245    Expense   60000
# 246    Expense   10000
# 247    Expense    5400
# 248    Expense   25000
# 249    Expense    3600
# 250    Expense    9000
# 251    Expense   10800
# 252    Expense  180000
# 253    Expense   12600
# 255    Expense   27200
# 260    Expense   27000
# 261    Expense   68400
# 262    Expense   50000
# 263    Expense   60000
# 264    Expense   10000
# 265    Expense    7200
# 266    Expense   54000
# 267    Expense    5000
# 268    Expense   14000
# 269    Expense   40000
# 270    Expense  234000
# 271    Expense   12600
# 272    Expense   41800
# 278    Expense   27000
# 279    Expense   68400
# 280    Expense   50000
# 281    Expense   60000
# 282    Expense   10000
# 283    Expense    5400
# 284    Expense   54000
# 285    Expense    5000
# 286    Expense   13000
# 287    Expense   35000
# 288    Expense  234000
# 289    Expense   12600
# 290    Expense   21700
# 296    Expense   27000
# 297    Expense   68400
# 298    Expense   40000
# 299    Expense   60000
# 300    Expense   10000
# 301    Expense    3600
# 302    Expense   54000
# 303    Expense    3600
# 304    Expense    9000
# 305    Expense   10800
# 306    Expense  234000
# 307    Expense   12600
# 308    Expense   27000
# 314    Expense   36000
# 315    Expense   68400
# 316    Expense   20000
# 317    Expense   55000
# 318    Expense   10000
# 319    Expense    3600
# 320    Expense   54000
# 321    Expense    3600
# 322    Expense    9000
# 323    Expense   10800
# 324    Expense  200000
# 325    Expense   12600
# 326    Expense   23800
# 330    Expense   36000
# 331    Expense   68400
# 332    Expense   20000
# 333    Expense   70000
# 334    Expense   10000
# 335    Expense    5400
# 336    Expense   25000
# 337    Expense    3600
# 338    Expense   10000
# 339    Expense   30000
# 340    Expense  200000
# 341    Expense   12600
# 342    Expense   15000
# 345    Expense   36000
# 346    Expense   72000
# 347    Expense   20000
# 348    Expense   70000
# 349    Expense   10000
# 350    Expense    3600
# 351    Expense   25000
# 352    Expense    3600
# 353    Expense   10000
# 354    Expense   30000
# 355    Expense  200000
# 356    Expense   12600
# 357    Expense   34300
# 360    Expense   36000
# 361    Expense   72000
# 362    Expense   30000
# 363    Expense   70000
# 364    Expense   10000
# 365    Expense    7200
# 366    Expense   25000
# 367    Expense    5400
# 368    Expense   12000
# 369    Expense   45000
# 370    Expense  200000
# 371    Expense   12600
# 372    Expense   25200
# 375    Expense   36000
# 376    Expense   72000
# 377    Expense   50000
# 378    Expense   70000
# 379    Expense   10000
# 380    Expense   14400
# 381    Expense   25000
# 382    Expense    6000
# 383    Expense   15000
# 384    Expense   50000
# 385    Expense  200000
# 386    Expense   12600
# 387    Expense   60000
# 390    Expense   15000
# 391    Expense   30000
# 392    Expense   40000
# 393    Expense   52000
# 394    Expense    5000
# 395    Expense    5000
# 396    Expense   30000
# 397    Expense    4000
# 398    Expense    9000
# 399    Expense   10000
# 400    Expense  100000
# 401    Expense    7000
# 402    Expense   52000
# 403    Expense   39000
# 406    Expense   15000
# 407    Expense   30000
# 408    Expense   40000
# 409    Expense   52000
# 410    Expense    5000
# 411    Expense    5000
# 412    Expense   30000
# 413    Expense    4000
# 414    Expense    8000
# 415    Expense   10000
# 416    Expense  100000
# 417    Expense    7000
# 418    Expense   27000
# 421    Expense   15000
# 422    Expense   30000
# 423    Expense   20000
# 424    Expense   52000
# 425    Expense    5000
# 426    Expense    3000
# 427    Expense   30000
# 428    Expense    2000
# 429    Expense    5000
# 430    Expense    7000
# 431    Expense  100000
# 432    Expense    7000
# 433    Expense   20000
# 436    Expense   15000
# 437    Expense   30000
# 438    Expense   20000
# 439    Expense   52000
# 440    Expense    5000
# 441    Expense    3000
# 442    Expense   30000
# 443    Expense    2000
# 444    Expense    5000
# 445    Expense    6000
# 446    Expense  100000
# 447    Expense    7000
# 448    Expense   31000
# 451    Expense   15000
# 452    Expense   38000
# 453    Expense   40000
# 454    Expense   52000
# 455    Expense    5000
# 456    Expense    4000
# 457    Expense   30000
# 458    Expense    4000
# 459    Expense    8000
# 460    Expense    9000
# 461    Expense  130000
# 462    Expense    7000
# 463    Expense   56700
# 466    Expense   15000
# 467    Expense   38000
# 468    Expense   40000
# 469    Expense   52000
# 470    Expense    5000
# 471    Expense    3000
# 472    Expense   30000
# 473    Expense    3000
# 474    Expense    9000
# 475    Expense    8000
# 476    Expense  130000
# 477    Expense    7000
# 478    Expense   30300
# 481    Expense   15000
# 482    Expense   38000
# 483    Expense   30000
# 484    Expense   45000
# 485    Expense    5000
# 486    Expense    2000
# 487    Expense   30000
# 488    Expense    2000
# 489    Expense    5000
# 490    Expense    6000
# 491    Expense  130000
# 492    Expense    7000
# 493    Expense   18600
# 496    Expense   20000
# 497    Expense   38000
# 498    Expense   20000
# 499    Expense   45000
# 500    Expense    5000
# 501    Expense    2000
# 502    Expense   30000
# 503    Expense    2000
# 504    Expense    5000
# 505    Expense    6000
# 506    Expense  130000
# 507    Expense    7000
# 510    Expense   26300
# 514    Expense   20000
# 515    Expense   38000
# 516    Expense   15000
# 517    Expense   45000
# 518    Expense    5000
# 519    Expense    3000
# 520    Expense   30000
# 521    Expense    2000
# 522    Expense    4000
# 523    Expense    6000
# 524    Expense  130000
# 525    Expense    7000
# 528    Expense   22000
# 532    Expense   20000
# 533    Expense   40000
# 534    Expense   15000
# 535    Expense   45000
# 536    Expense    5000
# 537    Expense    2000
# 538    Expense   30000
# 539    Expense    2000
# 540    Expense    4000
# 541    Expense    6000
# 542    Expense  110000
# 543    Expense    7000
# 546    Expense   15300
# 550    Expense   20000
# 551    Expense   40000
# 552    Expense   30000
# 553    Expense   45000
# 554    Expense    5000
# 555    Expense    4000
# 556    Expense   30000
# 557    Expense    3000
# 558    Expense    3000
# 559    Expense    7000
# 560    Expense  110000
# 561    Expense    7000
# 564    Expense   36700
# 568    Expense   20000
# 569    Expense   40000
# 570    Expense   40000
# 571    Expense   50000
# 572    Expense    5000
# 573    Expense    8000
# 574    Expense   30000
# 575    Expense    4000
# 576    Expense    7000
# 577    Expense    9000
# 578    Expense  110000
# 579    Expense    7000

# %%
#total rev by month

tot_rev_by_month = trend_rev_extract.groupby(['mon_no','Month_name'])['Amount'].sum().reset_index(name= 'tot_rev').sort_values('mon_no',ascending = True)
tot_rev_by_month
# Out:
#     mon_no Month_name  tot_rev
# 0        1        Jan  1949000
# 1        2        Feb  1567700
# 2        3        Mar  1313350
# 3        4        Apr  1156100
# 4        5        May  1698500
# 5        6        Jun  1719200
# 6        7        Jul  1400050
# 7        8        Aug  1304850
# 8        9        Sep  1120890
# 9       10        Oct  1322475
# 10      11        Nov  1277530
# 11      12        Dec  1730175

# %%
sns.set_color_codes('pastel')
sns.lineplot(x= 'Month_name', y= 'tot_rev', data= tot_rev_by_month, label = 'Total Revenue by Month')
# Out:
# <Axes: xlabel='Month_name', ylabel='tot_rev'>

# %%
#total exp by month
tot_exp_by_month = trend_exp_extract.groupby(['mon_no','Month_name'])['Amount'].sum().reset_index(name= 'tot_exp').sort_values('mon_no', ascending = True)
tot_exp_by_month
# Out:
#     mon_no Month_name  tot_exp
# 0        1        Jan  1254500
# 1        2        Feb  1089000
# 2        3        Mar  1010800
# 3        4        Apr   963400
# 4        5        May  1230900
# 5        6        Jun  1226100
# 6        7        Jul  1111200
# 7        8        Aug  1036300
# 8        9        Sep  1029300
# 9       10        Oct  1027400
# 10      11        Nov  1067600
# 11      12        Dec  1199200

# %%
sns.lineplot(x = 'Month_name', y= 'tot_exp', data= tot_exp_by_month)
# Out:
# <Axes: xlabel='Month_name', ylabel='tot_exp'>

# %%
#month over month change in revenue

tot_rev_by_month['mom_diff'] = tot_rev_by_month['tot_rev'] - tot_rev_by_month['tot_rev'].shift(1)
tot_rev_by_month['mom_%_change'] = tot_rev_by_month['tot_rev'].pct_change().round(3) *100
tot_rev_by_month.fillna(0, inplace= True)
mom_revv  = tot_rev_by_month

mom_revv
# Out:
#     mon_no Month_name  tot_rev  mom_diff  mom_%_change
# 0        1        Jan  1949000       0.0           0.0
# 1        2        Feb  1567700 -381300.0         -19.6
# 2        3        Mar  1313350 -254350.0         -16.2
# 3        4        Apr  1156100 -157250.0         -12.0
# 4        5        May  1698500  542400.0          46.9
# 5        6        Jun  1719200   20700.0           1.2
# 6        7        Jul  1400050 -319150.0         -18.6
# 7        8        Aug  1304850  -95200.0          -6.8
# 8        9        Sep  1120890 -183960.0         -14.1
# 9       10        Oct  1322475  201585.0          18.0
# 10      11        Nov  1277530  -44945.0          -3.4
# 11      12        Dec  1730175  452645.0          35.4

# %%
sns.barplot(x= 'Month_name', y = 'mom_%_change', color= 'r', data = mom_revv)
# Out:
# <Axes: xlabel='Month_name', ylabel='mom_%_change'>

# %%
#mom diff and percentage change in expenses

tot_exp_by_month.head()

tot_exp_by_month['mom_diff'] = tot_exp_by_month['tot_exp'] - tot_exp_by_month['tot_exp'].shift(1)
tot_exp_by_month['mom_%_change'] = tot_exp_by_month['tot_exp'].pct_change().round(3)*100
tot_exp_by_month.fillna(0, inplace= True)


mom_expp = tot_exp_by_month

mom_expp
# Out:
#     mon_no Month_name  tot_exp  mom_diff  mom_%_change
# 0        1        Jan  1254500       0.0           0.0
# 1        2        Feb  1089000 -165500.0         -13.2
# 2        3        Mar  1010800  -78200.0          -7.2
# 3        4        Apr   963400  -47400.0          -4.7
# 4        5        May  1230900  267500.0          27.8
# 5        6        Jun  1226100   -4800.0          -0.4
# 6        7        Jul  1111200 -114900.0          -9.4
# 7        8        Aug  1036300  -74900.0          -6.7
# 8        9        Sep  1029300   -7000.0          -0.7
# 9       10        Oct  1027400   -1900.0          -0.2
# 10      11        Nov  1067600   40200.0           3.9
# 11      12        Dec  1199200  131600.0          12.3

# %%
sns.barplot(x= 'Month_name', y = 'mom_%_change', color= 'r', data = mom_expp)
# Out:
# <Axes: xlabel='Month_name', ylabel='mom_%_change'>

# %% [markdown]
# Now we look at quarterly analysis

# %%
#rev by quarter
trend_rev_by_qtr = trend_rev_extract.groupby('Quarter')['Amount'].sum().reset_index(name='tot_rev').sort_values('Quarter', ascending= True)
trend_rev_by_qtr['mom_diff'] = trend_rev_by_qtr['tot_rev'] - trend_rev_by_qtr['tot_rev'].shift(1)
trend_rev_by_qtr['mom_%_diff'] = trend_rev_by_qtr['tot_rev'].pct_change().round(3)*100
trend_rev_by_qtr.fillna(0, inplace = True)

trend_rev_by_qtr
# Out:
#   Quarter  tot_rev  mom_diff  mom_%_diff
# 0   qtr 1  4830050       0.0         0.0
# 1   qtr 2  4573800 -256250.0        -5.3
# 2   qtr 3  3825790 -748010.0       -16.4
# 3   qtr 4  4330180  504390.0        13.2

# %%
#change in expense by quarter
trend_exp_by_qtr = trend_exp_extract.groupby('Quarter')['Amount'].sum().reset_index(name='tot_exp').sort_values('Quarter', ascending= True)
trend_exp_by_qtr['mom_diff'] = trend_exp_by_qtr['tot_exp'] - trend_exp_by_qtr['tot_exp'].shift(1)
trend_exp_by_qtr['mom_%_diff'] = trend_exp_by_qtr['tot_exp'].pct_change().round(3)*100
trend_exp_by_qtr.fillna(0, inplace = True)

trend_exp_by_qtr
# Out:
#   Quarter  tot_exp  mom_diff  mom_%_diff
# 0   qtr 1  3354300       0.0         0.0
# 1   qtr 2  3420400   66100.0         2.0
# 2   qtr 3  3176800 -243600.0        -7.1
# 3   qtr 4  3294200  117400.0         3.7

# %% [markdown]
# Now we shall look into Performance for each business lines and carry out a monthly and quarterly analysis
#
# We shall start by assessing change in revenue and expenses for all business lines and expense subgroups

# %%
#month over month expenses difference and percentage difference for all three business lines
trend_exp_extract.head()

#expense by business line, exp group and subgroup
#Fin_data.groupby(['Month_name','Biz_line'])['Amount'].sum().reset_index(name= 'tot').sort_values(['Month_name', 'tot'], ascending= [True, False])
exp_by_biz_sub_grp = trend_exp_extract.groupby([ 'mon_no','Biz_line','Month_name'])['Amount'].sum().reset_index(name = 'tot_exp').sort_values(['Biz_line','mon_no', 'tot_exp'], ascending= [True, True, False])
exp_by_biz_sub_grp['mom_diff'] = exp_by_biz_sub_grp['tot_exp'] - exp_by_biz_sub_grp['tot_exp'].shift(1)
exp_by_biz_sub_grp['mom_%_diff'] = exp_by_biz_sub_grp['tot_exp'].pct_change().round(3)*100
exp_by_biz_sub_grp.fillna(0, inplace= True)
exp_by_biz_sub_grp.head()
# Out:
#     mon_no                         Biz_line Month_name  tot_exp  mom_diff  \
# 0        1  Nutrition and Food Supplements         Jan   231500       0.0
# 3        2  Nutrition and Food Supplements         Feb   230900    -600.0
# 6        3  Nutrition and Food Supplements         Mar   212600  -18300.0
# 9        4  Nutrition and Food Supplements         Apr   213800    1200.0
# 12       5  Nutrition and Food Supplements         May   233900   20100.0
#
#     mom_%_diff
# 0          0.0
# 3         -0.3
# 6         -7.9
# 9          0.6
# 12         9.4

# %%
sns.barplot(x = 'Month_name', y= 'mom_%_diff', hue= 'Biz_line', color = 'b', data= exp_by_biz_sub_grp)
# Out:
# C:\Users\djibr\AppData\Local\Temp\ipykernel_16340\2752230754.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:b'` for the same effect.
#
#   sns.barplot(x = 'Month_name', y= 'mom_%_diff', hue= 'Biz_line', color = 'b', data= exp_by_biz_sub_grp)
# <Axes: xlabel='Month_name', ylabel='mom_%_diff'>

# %%
#we look into the mom diff and percentage diff in expenses for each business line

exp_by_biz_sub_grp = trend_exp_extract.groupby([ 'mon_no','Biz_line','Month_name'])['Amount'].sum().reset_index(name = 'tot_exp').sort_values(['Biz_line','mon_no', 'tot_exp'], ascending= [True, True, False])

def exp_mom_cal_and_pct(df):
    df['mom_diff'] = df['tot_exp'] - df['tot_exp'].shift(1)
    df['mom_%_diff'] = df['tot_exp'].pct_change().round(3)*100
    df.iloc[0, df.columns.get_loc('mom_diff')] = 0.0
    df.iloc[0, df.columns.get_loc('mom_%_diff')] = 0.0

    return df

exp_by_biz_sub_grp = exp_by_biz_sub_grp.groupby('Biz_line').apply(exp_mom_cal_and_pct).reset_index(drop= True)

exp_by_biz_sub_grp
# Out:
# C:\Users\djibr\AppData\Local\Temp\ipykernel_16340\3093412946.py:13: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   exp_by_biz_sub_grp = exp_by_biz_sub_grp.groupby('Biz_line').apply(exp_mom_cal_and_pct).reset_index(drop= True)
#     mon_no                         Biz_line Month_name  tot_exp  mom_diff  \
# 0        1  Nutrition and Food Supplements         Jan   231500       0.0
# 1        2  Nutrition and Food Supplements         Feb   230900    -600.0
# 2        3  Nutrition and Food Supplements         Mar   212600  -18300.0
# 3        4  Nutrition and Food Supplements         Apr   213800    1200.0
# 4        5  Nutrition and Food Supplements         May   233900   20100.0
# 5        6  Nutrition and Food Supplements         Jun   233300    -600.0
# 6        7  Nutrition and Food Supplements         Jul   205900  -27400.0
# 7        8  Nutrition and Food Supplements         Aug   200900   -5000.0
# 8        9  Nutrition and Food Supplements         Sep   192000   -8900.0
# 9       10  Nutrition and Food Supplements         Oct   192300     300.0
# 10      11  Nutrition and Food Supplements         Nov   197900    5600.0
# 11      12  Nutrition and Food Supplements         Dec   211500   13600.0
# 12       1                 Sports equipment        Jan   664000       0.0
# 13       2                 Sports equipment        Feb   513100 -150900.0
# 14       3                 Sports equipment        Mar   495200  -17900.0
# 15       4                 Sports equipment        Apr   454600  -40600.0
# 16       5                 Sports equipment        May   624000  169400.0
# 17       6                 Sports equipment        Jun   596100  -27900.0
# 18       7                 Sports equipment        Jul   560000  -36100.0
# 19       8                 Sports equipment        Aug   506800  -53200.0
# 20       9                 Sports equipment        Sep   506000    -800.0
# 21      10                 Sports equipment        Oct   527100   21100.0
# 22      11                 Sports equipment        Nov   550400   23300.0
# 23      12                 Sports equipment        Dec   621000   70600.0
# 24       1                       Sportswear        Jan   359000       0.0
# 25       2                       Sportswear        Feb   345000  -14000.0
# 26       3                       Sportswear        Mar   303000  -42000.0
# 27       4                       Sportswear        Apr   295000   -8000.0
# 28       5                       Sportswear        May   373000   78000.0
# 29       6                       Sportswear        Jun   396700   23700.0
# 30       7                       Sportswear        Jul   345300  -51400.0
# 31       8                       Sportswear        Aug   328600  -16700.0
# 32       9                       Sportswear        Sep   331300    2700.0
# 33      10                       Sportswear        Oct   308000  -23300.0
# 34      11                       Sportswear        Nov   319300   11300.0
# 35      12                       Sportswear        Dec   366700   47400.0
#
#     mom_%_diff
# 0          0.0
# 1         -0.3
# 2         -7.9
# 3          0.6
# 4          9.4
# 5         -0.3
# 6        -11.7
# 7         -2.4
# 8         -4.4
# 9          0.2
# 10         2.9
# 11         6.9
# 12         0.0
# 13       -22.7
# 14        -3.5
# 15        -8.2
# 16        37.3
# 17        -4.5
# 18        -6.1
# 19        -9.5
# 20        -0.2
# 21         4.2
# 22         4.4
# 23        12.8
# 24         0.0
# 25        -3.9
# 26       -12.2
# 27        -2.6
# 28        26.4
# 29         6.4
# 30       -13.0
# 31        -4.8
# 32         0.8
# 33        -7.0
# 34         3.7
# 35        14.8

# %%
# month over month change in expenses for expense groups

exp_by_exp_grp = trend_exp_extract.groupby([ 'mon_no','Month_name','Biz_line' ,'Rev_exp_group'])['Amount'].sum().reset_index(name = 'tot_exp').sort_values(['Biz_line','Rev_exp_group','mon_no'], ascending= [True, True, True])
exp_by_exp_grp.groupby('Rev_exp_group').apply(exp_mom_cal_and_pct).reset_index(drop= True)
# Out:
# C:\Users\djibr\AppData\Local\Temp\ipykernel_16340\4241562597.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# 62        3        Mar                       Sportswear  Interest and tax
# 63        4        Apr                       Sportswear  Interest and tax
# 64        5        May                       Sportswear  Interest and tax
# 65        6        Jun                       Sportswear  Interest and tax
# 66        7        Jul                       Sportswear  Interest and tax
# 67        8        Aug                       Sportswear  Interest and tax
# 68        9        Sep                       Sportswear  Interest and tax
# 69       10        Oct                       Sportswear  Interest and tax
# 70       11        Nov                       Sportswear  Interest and tax
# 71       12        Dec                       Sportswear  Interest and tax
# 72        1        Jan  Nutrition and Food Supplements               Opex
# 73        2        Feb  Nutrition and Food Supplements               Opex
# 74        3        Mar  Nutrition and Food Supplements               Opex
# 75        4        Apr  Nutrition and Food Supplements               Opex
# 76        5        May  Nutrition and Food Supplements               Opex
# 77        6        Jun  Nutrition and Food Supplements               Opex
# 78        7        Jul  Nutrition and Food Supplements               Opex
# 79        8        Aug  Nutrition and Food Supplements               Opex
# 80        9        Sep  Nutrition and Food Supplements               Opex
# 81       10        Oct  Nutrition and Food Supplements               Opex
# 82       11        Nov  Nutrition and Food Supplements               Opex
# 83       12        Dec  Nutrition and Food Supplements               Opex
# 84        1        Jan                 Sports equipment              Opex
# 85        2        Feb                 Sports equipment              Opex
# 86        3        Mar                 Sports equipment              Opex
# 87        4        Apr                 Sports equipment              Opex
# 88        5        May                 Sports equipment              Opex
# 89        6        Jun                 Sports equipment              Opex
# 90        7        Jul                 Sports equipment              Opex
# 91        8        Aug                 Sports equipment              Opex
# 92        9        Sep                 Sports equipment              Opex
# 93       10        Oct                 Sports equipment              Opex
# 94       11        Nov                 Sports equipment              Opex
# 95       12        Dec                 Sports equipment              Opex
# 96        1        Jan                       Sportswear              Opex
# 97        2        Feb                       Sportswear              Opex
# 98        3        Mar                       Sportswear              Opex
# 99        4        Apr                       Sportswear              Opex
# 100       5        May                       Sportswear              Opex
# 101       6        Jun                       Sportswear              Opex
# 102       7        Jul                       Sportswear              Opex
# 103       8        Aug                       Sportswear              Opex
# 104       9        Sep                       Sportswear              Opex
# 105      10        Oct                       Sportswear              Opex
# 106      11        Nov                       Sportswear              Opex
# 107      12        Dec                       Sportswear              Opex
#
#      tot_exp  mom_diff  mom_%_diff
# 0      94000       0.0         0.0
# 1      93400    -600.0        -0.6
# 2      90700   -2700.0        -2.9
# 3      91900    1200.0         1.3
# 4      94300    2400.0         2.6
# 5      94000    -300.0        -0.3
# 6      76900  -17100.0       -18.2
# 7      76900       0.0         0.0
# 8      75700   -1200.0        -1.6
# 9      75700       0.0         0.0
# 10     75700       0.0         0.0
# 11     78100    2400.0         3.2
# 12    408600  330500.0       423.2
# 13    254600 -154000.0       -37.7
# 14    271800   17200.0         6.8
# 15    241000  -30800.0       -11.3
# 16    359600  118600.0        49.2
# 17    353600   -6000.0        -1.7
# 18    324000  -29600.0        -8.4
# 19    290000  -34000.0       -10.5
# 20    281200   -8800.0        -3.0
# 21    281200       0.0         0.0
# 22    300000   18800.0         6.7
# 23    308600    8600.0         2.9
# 24    160000 -148600.0       -48.2
# 25    159000   -1000.0        -0.6
# 26    151000   -8000.0        -5.0
# 27    150000   -1000.0        -0.7
# 28    188000   38000.0        25.3
# 29    187000   -1000.0        -0.5
# 30    180000   -7000.0        -3.7
# 31    180000       0.0         0.0
# 32    179000   -1000.0        -0.6
# 33    159000  -20000.0       -11.2
# 34    160000    1000.0         0.6
# 35    167000    7000.0         4.4
# 36     12000       0.0         0.0
# 37     12000       0.0         0.0
# 38     12000       0.0         0.0
# 39     12000       0.0         0.0
# 40     12000       0.0         0.0
# 41     12000       0.0         0.0
# 42     12000       0.0         0.0
# 43     12000       0.0         0.0
# 44     12000       0.0         0.0
# 45     12000       0.0         0.0
# 46     12000       0.0         0.0
# 47     12000       0.0         0.0
# 48     49000   37000.0       308.3
# 49     48500    -500.0        -1.0
# 50     37000  -11500.0       -23.7
# 51     27200   -9800.0       -26.5
# 52     41800   14600.0        53.7
# 53     21700  -20100.0       -48.1
# 54     27000    5300.0        24.4
# 55     23800   -3200.0       -11.9
# 56     15000   -8800.0       -37.0
# 57     34300   19300.0       128.7
# 58     25200   -9100.0       -26.5
# 59     60000   34800.0       138.1
# 60     52000   -8000.0       -13.3
# 61     39000  -13000.0       -25.0
# 62     27000  -12000.0       -30.8
# 63     20000   -7000.0       -25.9
# 64     31000   11000.0        55.0
# 65     56700   25700.0        82.9
# 66     30300  -26400.0       -46.6
# 67     18600  -11700.0       -38.6
# 68     26300    7700.0        41.4
# 69     22000   -4300.0       -16.3
# 70     15300   -6700.0       -30.5
# 71     36700   21400.0       139.9
# 72    125500       0.0         0.0
# 73    125500       0.0         0.0
# 74    109900  -15600.0       -12.4
# 75    109900       0.0         0.0
# 76    127600   17700.0        16.1
# 77    127300    -300.0        -0.2
# 78    117000  -10300.0        -8.1
# 79    112000   -5000.0        -4.3
# 80    104300   -7700.0        -6.9
# 81    104600     300.0         0.3
# 82    110200    5600.0         5.4
# 83    121400   11200.0        10.2
# 84    206400   85000.0        70.0
# 85    210000    3600.0         1.7
# 86    186400  -23600.0       -11.2
# 87    186400       0.0         0.0
# 88    222600   36200.0        19.4
# 89    220800   -1800.0        -0.8
# 90    209000  -11800.0        -5.3
# 91    193000  -16000.0        -7.7
# 92    209800   16800.0         8.7
# 93    211600    1800.0         0.9
# 94    225200   13600.0         6.4
# 95    252400   27200.0        12.1
# 96    147000 -105400.0       -41.8
# 97    147000       0.0         0.0
# 98    125000  -22000.0       -15.0
# 99    125000       0.0         0.0
# 100   154000   29000.0        23.2
# 101   153000   -1000.0        -0.6
# 102   135000  -18000.0       -11.8
# 103   130000   -5000.0        -3.7
# 104   126000   -4000.0        -3.1
# 105   127000    1000.0         0.8
# 106   144000   17000.0        13.4
# 107   163000   19000.0        13.2

# %%
# month over month change and percentage change in expenses for expense subgroups

exp_by_exp_sub_grp = trend_exp_extract.groupby([ 'mon_no','Expense_subgroup','Month_name'])['Amount'].sum().reset_index(name = 'tot_exp').sort_values(['Expense_subgroup','mon_no', 'tot_exp'], ascending= [True, True, False])
exp_by_exp_sub_grp =  exp_by_exp_sub_grp.groupby('Expense_subgroup').apply(exp_mom_cal_and_pct).reset_index(drop = True)
# Out:
# C:\Users\djibr\AppData\Local\Temp\ipykernel_16340\1592899084.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   exp_by_exp_sub_grp =  exp_by_exp_sub_grp.groupby('Expense_subgroup').apply(exp_mom_cal_and_pct).reset_index(drop = True)

# %%
plt.figure(figsize =(10, 8))
sns.barplot(x= 'Month_name', y= 'mom_%_diff', hue= 'Expense_subgroup', data= exp_by_exp_sub_grp)
# Out:
# <Axes: xlabel='Month_name', ylabel='mom_%_diff'>

# %%
#now we look into  month over month difference in revenue genrated from all business lines, rev group 

rev_by_biz_line =trend_rev_extract.groupby(['mon_no', 'Month_name', 'Biz_line'])['Amount'].sum().reset_index(name= 'tot_rev').sort_values(['Biz_line', 'mon_no'], ascending = [True, True])

#now we define the function to calculate our mom_diff and percentage change in revenue

def rev_mom_and_pct(df):
    df['mom_diff'] = df['tot_rev'] - df['tot_rev'].shift(1)
    df['mom_%_diff'] = df['tot_rev'].pct_change().round(3)*100
    df.iloc[0, df.columns.get_loc('mom_diff')] = 0.0
    df.iloc[0, df.columns.get_loc('mom_%_diff')] = 0.0
    return df

rev = rev_by_biz_line.groupby('Biz_line').apply(rev_mom_and_pct).reset_index(drop = True)
rev
# Out:
# C:\Users\djibr\AppData\Local\Temp\ipykernel_16340\503075658.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   rev = rev_by_biz_line.groupby('Biz_line').apply(rev_mom_and_pct).reset_index(drop = True)
#     mon_no Month_name                         Biz_line  tot_rev  mom_diff  \
# 0        1        Jan  Nutrition and Food Supplements    186000       0.0
# 1        2        Feb  Nutrition and Food Supplements    163200  -22800.0
# 2        3        Mar  Nutrition and Food Supplements    127350  -35850.0
# 3        4        Apr  Nutrition and Food Supplements    108600  -18750.0
# 4        5        May  Nutrition and Food Supplements    159000   50400.0
# 5        6        Jun  Nutrition and Food Supplements    185700   26700.0
# 6        7        Jul  Nutrition and Food Supplements    145050  -40650.0
# 7        8        Aug  Nutrition and Food Supplements    207750   62700.0
# 8        9        Sep  Nutrition and Food Supplements    135390  -72360.0
# 9       10        Oct  Nutrition and Food Supplements    130725   -4665.0
# 10      11        Nov  Nutrition and Food Supplements    125430   -5295.0
# 11      12        Dec  Nutrition and Food Supplements    169425   43995.0
# 12       1        Jan                 Sports equipment  1033000       0.0
# 13       2        Feb                 Sports equipment   775500 -257500.0
# 14       3        Mar                 Sports equipment   719500  -56000.0
# 15       4        Apr                 Sports equipment   629500  -90000.0
# 16       5        May                 Sports equipment   848500  219000.0
# 17       6        Jun                 Sports equipment   784500  -64000.0
# 18       7        Jul                 Sports equipment   721500  -63000.0
# 19       8        Aug                 Sports equipment   634600  -86900.0
# 20       9        Sep                 Sports equipment   490900 -143700.0
# 21      10        Oct                 Sports equipment   690000  199100.0
# 22      11        Nov                 Sports equipment   678000  -12000.0
# 23      12        Dec                 Sports equipment   903000  225000.0
# 24       1        Jan                       Sportswear   730000       0.0
# 25       2        Feb                       Sportswear   629000 -101000.0
# 26       3        Mar                       Sportswear   466500 -162500.0
# 27       4        Apr                       Sportswear   418000  -48500.0
# 28       5        May                       Sportswear   691000  273000.0
# 29       6        Jun                       Sportswear   749000   58000.0
# 30       7        Jul                       Sportswear   533500 -215500.0
# 31       8        Aug                       Sportswear   462500  -71000.0
# 32       9        Sep                       Sportswear   494600   32100.0
# 33      10        Oct                       Sportswear   501750    7150.0
# 34      11        Nov                       Sportswear   474100  -27650.0
# 35      12        Dec                       Sportswear   657750  183650.0
#
#     mom_%_diff
# 0          0.0
# 1        -12.3
# 2        -22.0
# 3        -14.7
# 4         46.4
# 5         16.8
# 6        -21.9
# 7         43.2
# 8        -34.8
# 9         -3.4
# 10        -4.1
# 11        35.1
# 12         0.0
# 13       -24.9
# 14        -7.2
# 15       -12.5
# 16        34.8
# 17        -7.5
# 18        -8.0
# 19       -12.0
# 20       -22.6
# 21        40.6
# 22        -1.7
# 23        33.2
# 24         0.0
# 25       -13.8
# 26       -25.8
# 27       -10.4
# 28        65.3
# 29         8.4
# 30       -28.8
# 31       -13.3
# 32         6.9
# 33         1.4
# 34        -5.5
# 35        38.7

# %%
sns.barplot(x= 'Month_name', y= 'mom_%_diff', hue= 'Biz_line', data= rev )
# Out:
# <Axes: xlabel='Month_name', ylabel='mom_%_diff'>

# %%
# month over month change and percentage change in revenue generated by various revenue groups

rev_by_rev_group = trend_rev_extract.groupby(['mon_no', 'Rev_exp_group', 'Month_name'])['Amount'].sum().reset_index(name= 'tot_rev').sort_values(['Rev_exp_group', 'mon_no'], ascending = [True, True])

rev_by_rev_group.groupby('Rev_exp_group').apply(rev_mom_and_pct).reset_index(drop = True)
# Out:
# C:\Users\djibr\AppData\Local\Temp\ipykernel_16340\801339226.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   rev_by_rev_group.groupby('Rev_exp_group').apply(rev_mom_and_pct).reset_index(drop = True)
#     mon_no                         Rev_exp_group Month_name  tot_rev  \
# 0        1  Consulting and professional services        Jan   495000
# 1        2  Consulting and professional services        Feb   292500
# 2        3  Consulting and professional services        Mar   195000
# 3        4  Consulting and professional services        Apr   193500
# 4        5  Consulting and professional services        May   280800
# 5        6  Consulting and professional services        Jun   289200
# 6        7  Consulting and professional services        Jul   169500
# 7        8  Consulting and professional services        Aug   210000
# 8        9  Consulting and professional services        Sep   138000
# 9       10  Consulting and professional services        Oct   142800
# 10      11  Consulting and professional services        Nov   139800
# 11      12  Consulting and professional services        Dec   270900
# 12       1                          Other income        Jan    91000
# 13       2                          Other income        Feb    78500
# 14       3                          Other income        Mar    71100
# 15       4                          Other income        Apr    74800
# 16       5                          Other income        May   121000
# 17       6                          Other income        Jun   100700
# 18       7                          Other income        Jul    67000
# 19       8                          Other income        Aug    47600
# 20       9                          Other income        Sep    52490
# 21      10                          Other income        Oct    99000
# 22      11                          Other income        Nov    67000
# 23      12                          Other income        Dec    96000
# 24       1                                 Sales        Jan  1363000
# 25       2                                 Sales        Feb  1196700
# 26       3                                 Sales        Mar  1047250
# 27       4                                 Sales        Apr   887800
# 28       5                                 Sales        May  1296700
# 29       6                                 Sales        Jun  1329300
# 30       7                                 Sales        Jul  1163550
# 31       8                                 Sales        Aug  1047250
# 32       9                                 Sales        Sep   930400
# 33      10                                 Sales        Oct  1080675
# 34      11                                 Sales        Nov  1070730
# 35      12                                 Sales        Dec  1363275
#
#     mom_diff  mom_%_diff
# 0        0.0         0.0
# 1  -202500.0       -40.9
# 2   -97500.0       -33.3
# 3    -1500.0        -0.8
# 4    87300.0        45.1
# 5     8400.0         3.0
# 6  -119700.0       -41.4
# 7    40500.0        23.9
# 8   -72000.0       -34.3
# 9     4800.0         3.5
# 10   -3000.0        -2.1
# 11  131100.0        93.8
# 12       0.0         0.0
# 13  -12500.0       -13.7
# 14   -7400.0        -9.4
# 15    3700.0         5.2
# 16   46200.0        61.8
# 17  -20300.0       -16.8
# 18  -33700.0       -33.5
# 19  -19400.0       -29.0
# 20    4890.0        10.3
# 21   46510.0        88.6
# 22  -32000.0       -32.3
# 23   29000.0        43.3
# 24       0.0         0.0
# 25 -166300.0       -12.2
# 26 -149450.0       -12.5
# 27 -159450.0       -15.2
# 28  408900.0        46.1
# 29   32600.0         2.5
# 30 -165750.0       -12.5
# 31 -116300.0       -10.0
# 32 -116850.0       -11.2
# 33  150275.0        16.2
# 34   -9945.0        -0.9
# 35  292545.0        27.3

# %%
#overall month over month diff in revenue generated and expenses incurred

rev_exp = Fin_data.groupby(['mon_no', 'Rev_or_exp', 'Month_name'])['Amount'].sum().reset_index(name= 'tot').sort_values(['Rev_or_exp', 'mon_no'], ascending = [True, True])

#now we define our mom and pct diff function

def mom_pct_diff(df):
    df['mom_diff'] = df['tot'] - df['tot'].shift(1)
    df['mom_%_diff'] = df['tot'].pct_change().round(3)*100
    df.iloc[0, df.columns.get_loc('mom_diff')] = 0.0
    df.iloc[0, df.columns.get_loc('mom_%_diff')] = 0.0
    return df

rev_exp_02= rev_exp.groupby('Rev_or_exp').apply(mom_pct_diff).reset_index(drop= True)
rev_exp_02
# Out:
# C:\Users\djibr\AppData\Local\Temp\ipykernel_16340\2368620440.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   rev_exp_02= rev_exp.groupby('Rev_or_exp').apply(mom_pct_diff).reset_index(drop= True)
#     mon_no Rev_or_exp Month_name      tot  mom_diff  mom_%_diff
# 0        1    Expense        Jan  1254500       0.0         0.0
# 1        2    Expense        Feb  1089000 -165500.0       -13.2
# 2        3    Expense        Mar  1010800  -78200.0        -7.2
# 3        4    Expense        Apr   963400  -47400.0        -4.7
# 4        5    Expense        May  1230900  267500.0        27.8
# 5        6    Expense        Jun  1226100   -4800.0        -0.4
# 6        7    Expense        Jul  1111200 -114900.0        -9.4
# 7        8    Expense        Aug  1036300  -74900.0        -6.7
# 8        9    Expense        Sep  1029300   -7000.0        -0.7
# 9       10    Expense        Oct  1027400   -1900.0        -0.2
# 10      11    Expense        Nov  1067600   40200.0         3.9
# 11      12    Expense        Dec  1199200  131600.0        12.3
# 12       1    Revenue        Jan  1949000       0.0         0.0
# 13       2    Revenue        Feb  1567700 -381300.0       -19.6
# 14       3    Revenue        Mar  1313350 -254350.0       -16.2
# 15       4    Revenue        Apr  1156100 -157250.0       -12.0
# 16       5    Revenue        May  1698500  542400.0        46.9
# 17       6    Revenue        Jun  1719200   20700.0         1.2
# 18       7    Revenue        Jul  1400050 -319150.0       -18.6
# 19       8    Revenue        Aug  1304850  -95200.0        -6.8
# 20       9    Revenue        Sep  1120890 -183960.0       -14.1
# 21      10    Revenue        Oct  1322475  201585.0        18.0
# 22      11    Revenue        Nov  1277530  -44945.0        -3.4
# 23      12    Revenue        Dec  1730175  452645.0        35.4

# %%
sns.barplot(x = 'Month_name', y= 'mom_%_diff', hue= 'Rev_or_exp', color= 'g', data = rev_exp_02)
# Out:
# C:\Users\djibr\AppData\Local\Temp\ipykernel_16340\1244399306.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:g'` for the same effect.
#
#   sns.barplot(x = 'Month_name', y= 'mom_%_diff', hue= 'Rev_or_exp', color= 'g', data = rev_exp_02)
# <Axes: xlabel='Month_name', ylabel='mom_%_diff'>

# %% [markdown]
# Profit analysis
#
# Here we will deive into the following:
# gross profit across business line and sub groups
# Trend analysis for gross profit across business lines and subgroups

# %%
trend_rev_extract.head()
# Out:
#    Month_name  mon_no Quarter    week week_day  \
# 0         Jan       1   qtr 1  week 5  Tuesday
# 1         Jan       1   qtr 1  week 5  Tuesday
# 2         Jan       1   qtr 1  week 5  Tuesday
# 16        Feb       2   qtr 1  week 4  Tuesday
# 17        Mar       3   qtr 1  week 4   Friday
#
#                            Biz_line                         Rev_exp_group  \
# 0   Nutrition and Food Supplements                                  Sales
# 1   Nutrition and Food Supplements   Consulting and professional services
# 2   Nutrition and Food Supplements                           Other income
# 16  Nutrition and Food Supplements   Consulting and professional services
# 17  Nutrition and Food Supplements   Consulting and professional services
#
#    Rev_or_exp  Amount
# 0     Revenue  153000
# 1     Revenue   27000
# 2     Revenue    6000
# 16    Revenue   22500
# 17    Revenue    9000

# %%
trend_exp_extract.head()
# Out:
#   Month_name  mon_no Quarter    week week_day  \
# 3        Jan       1   qtr 1  week 5  Tuesday
# 4        Jan       1   qtr 1  week 5  Tuesday
# 5        Jan       1   qtr 1  week 5  Tuesday
# 6        Jan       1   qtr 1  week 5  Tuesday
# 7        Jan       1   qtr 1  week 5  Tuesday
#
#                           Biz_line Rev_exp_group Expense_subgroup Rev_or_exp  \
# 3  Nutrition and Food Supplements           Opex             Rent    Expense
# 4  Nutrition and Food Supplements           Opex        Equipment    Expense
# 5  Nutrition and Food Supplements           Opex        Marketing    Expense
# 6  Nutrition and Food Supplements           Opex          Payroll    Expense
# 7  Nutrition and Food Supplements           Opex              R&D    Expense
#
#    Amount
# 3   15000
# 4    9000
# 5   30000
# 6   40000
# 7   30000

# %% [markdown]
# ##identifying profit margin across business lines
# profit_margin_ext = Fin_data.groupby(['Rev_or_exp', 'Biz_line', 'Rev_exp_group'])['Amount'].sum().reset_index(name= 'total')
#
# profit_margin = profit_margin_ext.pivot(index = ['Biz_line', 'Rev_exp_group'], columns= 'Rev_or_exp', values= 'total')
# profit_margin['Prof_margin'] = profit_margin['Revenue'] + profit_margin['Expense']
# profit_margin

# %%
# Gross profit across all business lines

def gp_ext(df):
   Expenses = df.loc[df['Rev_exp_group'] == 'COGS', 'Amount'].sum()
   Revenue = df.loc[df['Rev_or_exp'] == 'Revenue', 'Amount'].sum()

   return  pd.DataFrame({'Biz_line': [df.name], 'Revenue': [Revenue], 'Expenses': [Expenses]})

prof_mar_ext = Fin_data[['Rev_or_exp', 'Biz_line', 'Rev_exp_group', 'Amount']]
gross_profit = prof_mar_ext.groupby('Biz_line').apply(gp_ext).reset_index(drop= True)

gross_profit['Gross_profit'] = gross_profit['Revenue'] + gross_profit['Expenses']
gross_profit
# Out:
# C:\Users\djibr\AppData\Local\Temp\ipykernel_16340\2802251392.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   gross_profit = prof_mar_ext.groupby('Biz_line').apply(gp_ext).reset_index(drop= True)
#                           Biz_line  Revenue  Expenses  Gross_profit
# 0  Nutrition and Food Supplements   1843620   1017300       2860920
# 1                 Sports equipment  8908500   3674200      12582700
# 2                       Sportswear  6807700   2020000       8827700

# %%
sns.barplot(x = 'Biz_line', y= 'Gross_profit', hue= 'Gross_profit',  data= gross_profit)
# Out:
# <Axes: xlabel='Biz_line', ylabel='Gross_profit'>

# %%
# general gross profit over month
 
def gp_by_mon(df):
   Expenses = df.loc[df['Rev_exp_group'] == 'COGS', 'Amount'].sum()
   Revenue = df.loc[df['Rev_or_exp'] == 'Revenue', 'Amount'].sum()
   Month_name = df['Month_name'].iloc[0]
   mon_no = df['mon_no'].iloc[0]
   return  pd.DataFrame({'mon_no': [mon_no],'Month_name': [Month_name],'Revenue': [Revenue], 'Expenses': [Expenses]})

mom_gross_profit_ext = Fin_data[['mon_no','Month_name','Rev_or_exp', 'Rev_exp_group', 'Amount']]
gp_by_month = mom_gross_profit_ext.groupby(['mon_no','Month_name']).apply(gp_by_mon).reset_index(drop= True).sort_values('mon_no', ascending= True)

gp_by_month['Gross_profit'] = gp_by_month['Revenue'] + gp_by_month['Expenses']
gp_by_month

# month over month change in gross profit

gp_by_month['mom_diff'] = gp_by_month['Gross_profit'] -  gp_by_month['Gross_profit'].shift(1)
gp_by_month['mom_%_diff'] = gp_by_month['Gross_profit'].pct_change().round(3)*100

mom_gp_by_mon = gp_by_month
mom_gp_by_mon.fillna(0)
# Out:
# C:\Users\djibr\AppData\Local\Temp\ipykernel_16340\478927505.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   gp_by_month = mom_gross_profit_ext.groupby(['mon_no','Month_name']).apply(gp_by_mon).reset_index(drop= True).sort_values('mon_no', ascending= True)
#     mon_no Month_name  Revenue  Expenses  Gross_profit  mom_diff  mom_%_diff
# 0        1        Jan  1949000    662600       2611600       0.0         0.0
# 1        2        Feb  1567700    507000       2074700 -536900.0       -20.6
# 2        3        Mar  1313350    513500       1826850 -247850.0       -11.9
# 3        4        Apr  1156100    482900       1639000 -187850.0       -10.3
# 4        5        May  1698500    641900       2340400  701400.0        42.8
# 5        6        Jun  1719200    634600       2353800   13400.0         0.6
# 6        7        Jul  1400050    580900       1980950 -372850.0       -15.8
# 7        8        Aug  1304850    546900       1851750 -129200.0        -6.5
# 8        9        Sep  1120890    535900       1656790 -194960.0       -10.5
# 9       10        Oct  1322475    515900       1838375  181585.0        11.0
# 10      11        Nov  1277530    535700       1813230  -25145.0        -1.4
# 11      12        Dec  1730175    553700       2283875  470645.0        26.0

# %%
# df_melted = mom_gp_by_mon.melt(id_vars='Month_name', value_vars=['Revenue', 'Expenses'], 
#                                var_name='Type', value_name='Amount')

# df_melted

# %%
sns.lineplot(x = 'Month_name', y= 'mom_%_diff', data = mom_gp_by_mon  )
# Out:
# <Axes: xlabel='Month_name', ylabel='mom_%_diff'>

# %%
#identifying gross profit across biz_line over months

def gp_bizline(df):
   Expenses = df.loc[df['Rev_exp_group'] == 'COGS', 'Amount'].sum()
   Revenue = df.loc[df['Rev_or_exp'] == 'Revenue', 'Amount'].sum()
   Month_name = df['Month_name'].iloc[0]
   mon_no = df['mon_no'].iloc[0]
   Biz_line = df['Biz_line'].iloc[0]
   return  pd.DataFrame({'mon_no': [mon_no],'Month_name': [Month_name],'Biz_line': [Biz_line], 'Revenue': [Revenue], 'Expenses': [Expenses]})

gp_biz_line_ext = Fin_data[['mon_no','Month_name','Rev_or_exp', 'Biz_line', 'Rev_exp_group', 'Amount']]
gp_biz_line_by_mon = gp_biz_line_ext.groupby(['mon_no','Month_name','Biz_line']).apply(gp_bizline).reset_index(drop= True).sort_values(['Biz_line', 'mon_no'], ascending= [True, True])

gp_biz_line_by_mon['Gross_profit'] = gp_biz_line_by_mon['Revenue'] + gp_biz_line_by_mon['Expenses']
gp_biz_line_by_mon.head()
# Out:
# C:\Users\djibr\AppData\Local\Temp\ipykernel_16340\1221078824.py:12: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   gp_biz_line_by_mon = gp_biz_line_ext.groupby(['mon_no','Month_name','Biz_line']).apply(gp_bizline).reset_index(drop= True).sort_values(['Biz_line', 'mon_no'], ascending= [True, True])
#     mon_no Month_name                         Biz_line  Revenue  Expenses  \
# 0        1        Jan  Nutrition and Food Supplements    186000     94000
# 3        2        Feb  Nutrition and Food Supplements    163200     93400
# 6        3        Mar  Nutrition and Food Supplements    127350     90700
# 9        4        Apr  Nutrition and Food Supplements    108600     91900
# 12       5        May  Nutrition and Food Supplements    159000     94300
#
#     Gross_profit
# 0         280000
# 3         256600
# 6         218050
# 9         200500
# 12        253300

# %%
# month over month change in gross profit across all business lines

def mom_gp_pct_biz_line(df):
    df['mon_diff'] = df['Gross_profit'] - df['Gross_profit'].shift(1)
    df['mom_%_diff'] = df['Gross_profit'].pct_change().round(3)*100
    df.iloc[0, df.columns.get_loc('mon_diff')] = 0.0
    df.iloc[0, df.columns.get_loc('mom_%_diff')] = 0.0
    df.fillna(0, inplace = True)
    return df

mom_gp_by_biz_line = gp_biz_line_by_mon.groupby('Biz_line').apply(mom_gp_pct_biz_line).reset_index(drop = True)
mom_gp_by_biz_line
# Out:
# C:\Users\djibr\AppData\Local\Temp\ipykernel_16340\619781352.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   mom_gp_by_biz_line = gp_biz_line_by_mon.groupby('Biz_line').apply(mom_gp_pct_biz_line).reset_index(drop = True)
#     mon_no Month_name                         Biz_line  Revenue  Expenses  \
# 0        1        Jan  Nutrition and Food Supplements    186000     94000
# 1        2        Feb  Nutrition and Food Supplements    163200     93400
# 2        3        Mar  Nutrition and Food Supplements    127350     90700
# 3        4        Apr  Nutrition and Food Supplements    108600     91900
# 4        5        May  Nutrition and Food Supplements    159000     94300
# 5        6        Jun  Nutrition and Food Supplements    185700     94000
# 6        7        Jul  Nutrition and Food Supplements    145050     76900
# 7        8        Aug  Nutrition and Food Supplements    207750     76900
# 8        9        Sep  Nutrition and Food Supplements    135390     75700
# 9       10        Oct  Nutrition and Food Supplements    130725     75700
# 10      11        Nov  Nutrition and Food Supplements    125430     75700
# 11      12        Dec  Nutrition and Food Supplements    169425     78100
# 12       1        Jan                 Sports equipment  1033000    408600
# 13       2        Feb                 Sports equipment   775500    254600
# 14       3        Mar                 Sports equipment   719500    271800
# 15       4        Apr                 Sports equipment   629500    241000
# 16       5        May                 Sports equipment   848500    359600
# 17       6        Jun                 Sports equipment   784500    353600
# 18       7        Jul                 Sports equipment   721500    324000
# 19       8        Aug                 Sports equipment   634600    290000
# 20       9        Sep                 Sports equipment   490900    281200
# 21      10        Oct                 Sports equipment   690000    281200
# 22      11        Nov                 Sports equipment   678000    300000
# 23      12        Dec                 Sports equipment   903000    308600
# 24       1        Jan                       Sportswear   730000    160000
# 25       2        Feb                       Sportswear   629000    159000
# 26       3        Mar                       Sportswear   466500    151000
# 27       4        Apr                       Sportswear   418000    150000
# 28       5        May                       Sportswear   691000    188000
# 29       6        Jun                       Sportswear   749000    187000
# 30       7        Jul                       Sportswear   533500    180000
# 31       8        Aug                       Sportswear   462500    180000
# 32       9        Sep                       Sportswear   494600    179000
# 33      10        Oct                       Sportswear   501750    159000
# 34      11        Nov                       Sportswear   474100    160000
# 35      12        Dec                       Sportswear   657750    167000
#
#     Gross_profit  mon_diff  mom_%_diff
# 0         280000       0.0         0.0
# 1         256600  -23400.0        -8.4
# 2         218050  -38550.0       -15.0
# 3         200500  -17550.0        -8.0
# 4         253300   52800.0        26.3
# 5         279700   26400.0        10.4
# 6         221950  -57750.0       -20.6
# 7         284650   62700.0        28.2
# 8         211090  -73560.0       -25.8
# 9         206425   -4665.0        -2.2
# 10        201130   -5295.0        -2.6
# 11        247525   46395.0        23.1
# 12       1441600       0.0         0.0
# 13       1030100 -411500.0       -28.5
# 14        991300  -38800.0        -3.8
# 15        870500 -120800.0       -12.2
# 16       1208100  337600.0        38.8
# 17       1138100  -70000.0        -5.8
# 18       1045500  -92600.0        -8.1
# 19        924600 -120900.0       -11.6
# 20        772100 -152500.0       -16.5
# 21        971200  199100.0        25.8
# 22        978000    6800.0         0.7
# 23       1211600  233600.0        23.9
# 24        890000       0.0         0.0
# 25        788000 -102000.0       -11.5
# 26        617500 -170500.0       -21.6
# 27        568000  -49500.0        -8.0
# 28        879000  311000.0        54.8
# 29        936000   57000.0         6.5
# 30        713500 -222500.0       -23.8
# 31        642500  -71000.0       -10.0
# 32        673600   31100.0         4.8
# 33        660750  -12850.0        -1.9
# 34        634100  -26650.0        -4.0
# 35        824750  190650.0        30.1

# %%
# Operating Expenses analysis OPEX

opex_extract = trend_exp_extract.loc[trend_exp_extract['Rev_exp_group'] == 'Opex', ['Month_name', 'mon_no', 'Biz_line', 'Expense_subgroup', 'Amount']]
opex_extract

#opex by month

opex_by_mon = opex_extract.groupby(['mon_no', 'Month_name'])['Amount'].sum().reset_index(name= 'opex').sort_values('mon_no', ascending= True)

#opex across business lines

opex_biz_line = opex_extract.groupby('Biz_line')['Amount'].sum().reset_index(name = 'opex').sort_values('Biz_line',ascending = True)

#total ebit by across business lines by month

opex_by_mon_biz_line = opex_extract.groupby(['Biz_line', 'mon_no', 'Month_name'])['Amount'].sum().reset_index(name = 'tot_exp').sort_values(['Biz_line', 'mon_no', 'tot_exp'], ascending = [True, True, False])
opex_by_mon_biz_line.head()


# month over month difference in ebit across business lines
mom_opex = opex_by_mon_biz_line.groupby('Biz_line').apply(exp_mom_cal_and_pct).reset_index(drop= True)
mom_opex

#sns.lineplot(x= 'Month_name', y= 'mom_%_diff', hue= 'Biz_line', data= mom_opex)
# Out:
# C:\Users\djibr\AppData\Local\Temp\ipykernel_16340\2751987549.py:21: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   mom_opex = opex_by_mon_biz_line.groupby('Biz_line').apply(exp_mom_cal_and_pct).reset_index(drop= True)
#                            Biz_line  mon_no Month_name  tot_exp  mom_diff  \
# 0   Nutrition and Food Supplements        1        Jan   125500       0.0
# 1   Nutrition and Food Supplements        2        Feb   125500       0.0
# 2   Nutrition and Food Supplements        3        Mar   109900  -15600.0
# 3   Nutrition and Food Supplements        4        Apr   109900       0.0
# 4   Nutrition and Food Supplements        5        May   127600   17700.0
# 5   Nutrition and Food Supplements        6        Jun   127300    -300.0
# 6   Nutrition and Food Supplements        7        Jul   117000  -10300.0
# 7   Nutrition and Food Supplements        8        Aug   112000   -5000.0
# 8   Nutrition and Food Supplements        9        Sep   104300   -7700.0
# 9   Nutrition and Food Supplements       10        Oct   104600     300.0
# 10  Nutrition and Food Supplements       11        Nov   110200    5600.0
# 11  Nutrition and Food Supplements       12        Dec   121400   11200.0
# 12                 Sports equipment       1        Jan   206400       0.0
# 13                 Sports equipment       2        Feb   210000    3600.0
# 14                 Sports equipment       3        Mar   186400  -23600.0
# 15                 Sports equipment       4        Apr   186400       0.0
# 16                 Sports equipment       5        May   222600   36200.0
# 17                 Sports equipment       6        Jun   220800   -1800.0
# 18                 Sports equipment       7        Jul   209000  -11800.0
# 19                 Sports equipment       8        Aug   193000  -16000.0
# 20                 Sports equipment       9        Sep   209800   16800.0
# 21                 Sports equipment      10        Oct   211600    1800.0
# 22                 Sports equipment      11        Nov   225200   13600.0
# 23                 Sports equipment      12        Dec   252400   27200.0
# 24                       Sportswear       1        Jan   147000       0.0
# 25                       Sportswear       2        Feb   147000       0.0
# 26                       Sportswear       3        Mar   125000  -22000.0
# 27                       Sportswear       4        Apr   125000       0.0
# 28                       Sportswear       5        May   154000   29000.0
# 29                       Sportswear       6        Jun   153000   -1000.0
# 30                       Sportswear       7        Jul   135000  -18000.0
# 31                       Sportswear       8        Aug   130000   -5000.0
# 32                       Sportswear       9        Sep   126000   -4000.0
# 33                       Sportswear      10        Oct   127000    1000.0
# 34                       Sportswear      11        Nov   144000   17000.0
# 35                       Sportswear      12        Dec   163000   19000.0
#
#     mom_%_diff
# 0          0.0
# 1          0.0
# 2        -12.4
# 3          0.0
# 4         16.1
# 5         -0.2
# 6         -8.1
# 7         -4.3
# 8         -6.9
# 9          0.3
# 10         5.4
# 11        10.2
# 12         0.0
# 13         1.7
# 14       -11.2
# 15         0.0
# 16        19.4
# 17        -0.8
# 18        -5.3
# 19        -7.7
# 20         8.7
# 21         0.9
# 22         6.4
# 23        12.1
# 24         0.0
# 25         0.0
# 26       -15.0
# 27         0.0
# 28        23.2
# 29        -0.6
# 30       -11.8
# 31        -3.7
# 32        -3.1
# 33         0.8
# 34        13.4
# 35        13.2

# %%
opex_biz_line

# momth over month ebit diff across business lines
# Out:
#                           Biz_line     opex
# 0  Nutrition and Food Supplements   1395200
# 1                 Sports equipment  2533600
# 2                       Sportswear  1676000

# %%
gross_profit_ebit = gross_profit[['Biz_line', 'Gross_profit']]
gross_profit_ebit
# Out:
#                           Biz_line  Gross_profit
# 0  Nutrition and Food Supplements        2860920
# 1                 Sports equipment      12582700
# 2                       Sportswear       8827700

# %%
# Expenses Before Interests and Taxes analysis
ebit = gross_profit_ebit.merge(opex_biz_line, on= 'Biz_line', how= 'left')
ebit

#overall ebit analysis
gp = ebit['Gross_profit'].sum()
opex = ebit['opex'].sum()
ebit_df = pd.DataFrame({'gp': [gp], 
                       'opex': [opex]})

ebit_df['ebit'] = ebit_df['gp'] + ebit_df['opex']

ebit_df
# Out:
#          gp     opex      ebit
# 0  24271320  5604800  29876120

# %%
#ebit by business line
ebit['ebit'] = ebit['Gross_profit'] + ebit['opex']
ebit
# Out:
#                           Biz_line  Gross_profit     opex      ebit
# 0  Nutrition and Food Supplements        2860920  1395200   4256120
# 1                 Sports equipment      12582700  2533600  15116300
# 2                       Sportswear       8827700  1676000  10503700

# %%
#expenses before interest and taxes across months

ebit_by_mon_ext = opex_by_mon.merge(gp_by_month, on= 'Month_name', how= 'inner')
ebit_by_mon = ebit_by_mon_ext[['mon_no_x', 'Month_name', 'Gross_profit', 'opex']]


ebit_by_mon['ebit'] = ebit_by_mon['Gross_profit'] + ebit_by_mon['opex']
ebit_by_mon

#month over month change in ebit
ebit_by_mon['mom_diff'] = ebit_by_mon['ebit'] - ebit_by_mon['ebit'].shift(1)
ebit_by_mon['mom_%_diff'] = ebit_by_mon['ebit'].pct_change().round(3)*100
ebit_by_mon.fillna(0)
# Out:
# C:\Users\djibr\AppData\Local\Temp\ipykernel_16340\276059908.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ebit_by_mon['ebit'] = ebit_by_mon['Gross_profit'] + ebit_by_mon['opex']
# C:\Users\djibr\AppData\Local\Temp\ipykernel_16340\276059908.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ebit_by_mon['mom_diff'] = ebit_by_mon['ebit'] - ebit_by_mon['ebit'].shift(1)
# C:\Users\djibr\AppData\Local\Temp\ipykernel_16340\276059908.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ebit_by_mon['mom_%_diff'] = ebit_by_mon['ebit'].pct_change().round(3)*100
#     mon_no_x Month_name  Gross_profit    opex     ebit  mom_diff  mom_%_diff
# 0          1        Jan       2611600  478900  3090500       0.0         0.0
# 1          2        Feb       2074700  482500  2557200 -533300.0       -17.3
# 2          3        Mar       1826850  421300  2248150 -309050.0       -12.1
# 3          4        Apr       1639000  421300  2060300 -187850.0        -8.4
# 4          5        May       2340400  504200  2844600  784300.0        38.1
# 5          6        Jun       2353800  501100  2854900   10300.0         0.4
# 6          7        Jul       1980950  461000  2441950 -412950.0       -14.5
# 7          8        Aug       1851750  435000  2286750 -155200.0        -6.4
# 8          9        Sep       1656790  440100  2096890 -189860.0        -8.3
# 9         10        Oct       1838375  443200  2281575  184685.0         8.8
# 10        11        Nov       1813230  479400  2292630   11055.0         0.5
# 11        12        Dec       2283875  536800  2820675  528045.0        23.0

# %%
mom_opex.head()
# Out:
#                           Biz_line  mon_no Month_name  tot_exp  mom_diff  \
# 0  Nutrition and Food Supplements        1        Jan   125500       0.0
# 1  Nutrition and Food Supplements        2        Feb   125500       0.0
# 2  Nutrition and Food Supplements        3        Mar   109900  -15600.0
# 3  Nutrition and Food Supplements        4        Apr   109900       0.0
# 4  Nutrition and Food Supplements        5        May   127600   17700.0
#
#    mom_%_diff
# 0         0.0
# 1         0.0
# 2       -12.4
# 3         0.0
# 4        16.1

# %% [markdown]
# Interest and tax analysis

# %%
int_tax = Fin_data[Fin_data['Expense_subgroup'] == 'Interest and tax'].head()

int_tax_biz_line = int_tax.groupby('Biz_line')['Amount'].sum().reset_index(name= 'tot_int_tax'). sort_values('tot_int_tax', ascending = False)
int_tax_biz_line
# Out:
#                           Biz_line  tot_int_tax
# 0  Nutrition and Food Supplements         60000

# %%
#Net profit calculation

int_tax_ext = Fin_data.loc[Fin_data['Expense_subgroup'] == 'Interest and tax', ['mon_no', 'Month_name', 'Amount']]
int_tax_ext

int_tax_by_mon = int_tax_ext.groupby(['mon_no','Month_name'])['Amount'].sum().reset_index(name= 'int_tax').sort_values('mon_no', ascending = True)
int_tax_by_mon

#tax and ebit merge

net_prof_cal = ebit_by_mon.merge(int_tax_by_mon, on= 'Month_name', how = 'left')
net_prof_cal

#now we calculate the net profit

net_prof_cal['net_profit'] = net_prof_cal['ebit'] + net_prof_cal['int_tax']
net_prof_cal

#Now we calculate the month over month change in net profit

net_prof_cal['net_mom_diff'] = net_prof_cal['net_profit'] - net_prof_cal['net_profit'].shift(1)
net_prof_cal['net_mom_%_diff'] = net_prof_cal['net_profit'].pct_change().round(3)*100

net_prof_cal.fillna(0, inplace= True)

net_prof_cal
# Out:
#     mon_no_x Month_name  Gross_profit    opex     ebit  mom_diff  mom_%_diff  \
# 0          1        Jan       2611600  478900  3090500       0.0         0.0
# 1          2        Feb       2074700  482500  2557200 -533300.0       -17.3
# 2          3        Mar       1826850  421300  2248150 -309050.0       -12.1
# 3          4        Apr       1639000  421300  2060300 -187850.0        -8.4
# 4          5        May       2340400  504200  2844600  784300.0        38.1
# 5          6        Jun       2353800  501100  2854900   10300.0         0.4
# 6          7        Jul       1980950  461000  2441950 -412950.0       -14.5
# 7          8        Aug       1851750  435000  2286750 -155200.0        -6.4
# 8          9        Sep       1656790  440100  2096890 -189860.0        -8.3
# 9         10        Oct       1838375  443200  2281575  184685.0         8.8
# 10        11        Nov       1813230  479400  2292630   11055.0         0.5
# 11        12        Dec       2283875  536800  2820675  528045.0        23.0
#
#     mon_no  int_tax  net_profit  net_mom_diff  net_mom_%_diff
# 0        1   113000     3203500           0.0             0.0
# 1        2    99500     2656700     -546800.0           -17.1
# 2        3    76000     2324150     -332550.0           -12.5
# 3        4    59200     2119500     -204650.0            -8.8
# 4        5    84800     2929400      809900.0            38.2
# 5        6    90400     2945300       15900.0             0.5
# 6        7    69300     2511250     -434050.0           -14.7
# 7        8    54400     2341150     -170100.0            -6.8
# 8        9    53300     2150190     -190960.0            -8.2
# 9       10    68300     2349875      199685.0             9.3
# 10      11    52500     2345130       -4745.0            -0.2
# 11      12   108700     2929375      584245.0            24.9

# %%
Fin_data.head()
# Out:
#    Year Month_name  Month_sequence       Date  \
# 0  2023        Jan               1 2023-01-31
# 1  2023        Jan               1 2023-01-31
# 2  2023        Jan               1 2023-01-31
# 3  2023        Jan               1 2023-01-31
# 4  2023        Jan               1 2023-01-31
#
#                           Biz_line  Amount Expense_subgroup  \
# 0  Nutrition and Food Supplements   153000              NaN
# 1  Nutrition and Food Supplements    27000              NaN
# 2  Nutrition and Food Supplements     6000              NaN
# 3  Nutrition and Food Supplements    15000             Rent
# 4  Nutrition and Food Supplements     9000        Equipment
#
#                           Rev_exp_group Rev_or_exp    week Quarter  mon_no  \
# 0                                 Sales    Revenue  week 5   qtr 1       1
# 1  Consulting and professional services    Revenue  week 5   qtr 1       1
# 2                          Other income    Revenue  week 5   qtr 1       1
# 3                                  Opex    Expense  week 5   qtr 1       1
# 4                                  Opex    Expense  week 5   qtr 1       1
#
#    mon_day week_day
# 0       31  Tuesday
# 1       31  Tuesday
# 2       31  Tuesday
# 3       31  Tuesday
# 4       31  Tuesday

# %% [markdown]
# Predictive analytics

# %% [markdown]
# Revenue Forecast

# %%
trend_rev_extract
rev_forecast_ext = Fin_data.loc[Fin_data['Rev_or_exp'] == 'Revenue', ['Date', 'Year', 'Month_name', 'mon_no', 'Quarter', 'week_day', 'mon_day', 'Biz_line', 'Rev_exp_group', 'Amount']]
rev_forecast_ext

x = rev_forecast_ext[['Year','mon_no']]
y = rev_forecast_ext['Amount']

#to split our data into training and test data

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.2, random_state= 42)

#Now we select our model
model = LinearRegression()

#to train the model

model.fit(x_train, y_train)
#to predict using the model
y_pred = model.predict(x_test)

#to confirm the model/evaluate performance

mse = mean_squared_error(y_test, y_pred)

print(mse)
# Out:
# 37124311932.979256

# %%
from prophet import Prophet
