# %%
#here we import our datasets
import numpy as np
import pandas as pd

# %%
Email_fact_data = pd.read_csv("./Onyx_Data_Email_Fact_table.csv", index_col = "Email id")
Email_fact_data
# Out:
#                From Name           From seniority       From Department  \
# Email id
# 1           Leona McAree                  C-level  Executive Management
# 2           Leona McAree                  C-level  Executive Management
# 3           Leona McAree                  C-level  Executive Management
# 4           Leona McAree                  C-level  Executive Management
# 5           Leona McAree                  C-level  Executive Management
# ...                  ...                      ...                   ...
# 1193      Emmey Matoshin  Middle level management                 Sales
# 1194      Emmey Matoshin  Middle level management                 Sales
# 1195      Emmey Matoshin  Middle level management                 Sales
# 1196      Emmey Matoshin  Middle level management                 Sales
# 1197      Emmey Matoshin  Middle level management                 Sales
#
#                      To Name             To seniority           To Department  \
# Email id
# 1         Elsinore Waterland  Middle level management         Human Resources
# 2         Elsinore Waterland  Middle level management         Human Resources
# 3         Elsinore Waterland  Middle level management         Human Resources
# 4         Elsinore Waterland  Middle level management         Human Resources
# 5         Elsinore Waterland  Middle level management         Human Resources
# ...                      ...                      ...                     ...
# 1193         Blithe Arnaudet  Middle level management  Finance and Accounting
# 1194         Blithe Arnaudet  Middle level management  Finance and Accounting
# 1195         Blithe Arnaudet  Middle level management  Finance and Accounting
# 1196         Blithe Arnaudet  Middle level management  Finance and Accounting
# 1197         Blithe Arnaudet  Middle level management  Finance and Accounting
#
#                      Email topic       Date Sentiment Is opened?   Device  \
# Email id
# 1             Operational Issues  3/14/2024   neutral     opened  desktop
# 2              HR related topics  3/22/2024  positive     opened   mobile
# 3             Meeting Scheduling  3/26/2024   neutral   unopened  desktop
# 4              HR related topics  3/11/2024   neutral     opened   mobile
# 5              HR related topics  3/11/2024  positive     opened   mobile
# ...                          ...        ...       ...        ...      ...
# 1193      Finance and Accounting  3/28/2024  positive     opened   mobile
# 1194      Finance and Accounting   3/7/2024  negative     opened  desktop
# 1195          Operational Issues  3/14/2024   neutral     opened  desktop
# 1196          Meeting Scheduling   3/8/2024  positive     opened  desktop
# 1197      Finance and Accounting  3/23/2024   neutral     opened   mobile
#
#          Within work hours Within workdays
# Email id
# 1                      yes             yes
# 2                       no             yes
# 3                      yes             yes
# 4                      yes             yes
# 5                      yes             yes
# ...                    ...             ...
# 1193                   yes             yes
# 1194                   yes             yes
# 1195                    no             yes
# 1196                   yes             yes
# 1197                    no              no
#
# [1132 rows x 13 columns]

# %%
Email_dim = pd.read_csv("./Onyx_Data_Email_Dim_table.txt")
Email_dim
# Out:
#                         Name                   Department  \
# 0               Leona McAree         Executive Management
# 1   Constancia Di Bartolomeo         Executive Management
# 2          Corey Scandwright         Executive Management
# 3         Elsinore Waterland              Human Resources
# 4           Petronilla Mapes              Human Resources
# 5             Elbertine Dowe              Human Resources
# 6            Blithe Arnaudet       Finance and Accounting
# 7              Ozzy Jeffries       Finance and Accounting
# 8    Constantino FitzGilbert       Finance and Accounting
# 9               Traci Habbal                    Marketing
# 10           Roger Tabbernor                    Marketing
# 33               morly.finey@kochgroup.com             Professional
# 34           angie.penticost@kochgroup.com             Professional
# 35          maribelle.oliver@kochgroup.com             Professional
# 36            jeannie.moggan@kochgroup.com  Middle level management
# 37             faythe.vassel@kochgroup.com             Professional
# 38           maurine.golding@kochgroup.com             Professional
# 39             jorey.deguara@kochgroup.com  Middle level management
# 40         rodrique.coulston@kochgroup.com             Professional
# 41            lisette.loweth@kochgroup.com             Professional
# 42          minette.southard@kochgroup.com             Professional
# 43          theressa.tuddall@kochgroup.com             Professional
# 44                oran.benge@kochgroup.com             Professional
# 45              maggy.putson@kochgroup.com             Professional
# 46             barry.goundsy@kochgroup.com             Professional
#
#    Department color Department aura
# 0               red           aura1
# 1               red           aura1
# 2               red           aura1
# 3            yellow           aura2
# 4            yellow           aura2
# 5            yellow           aura2
# 6             green           aura3
# 7             green           aura3
# 8             green           aura3
# 9              blue           aura4
# 10             blue           aura4
# 11             blue           aura4
# 12             blue           aura4
# 13             blue           aura4
# 14             blue           aura4
# 15             gray           aura5
# 16             gray           aura5
# 17             gray           aura5
# 18             gray           aura5
# 19             gray           aura5
# 20             gray           aura5
# 21             gray           aura5
# 22             gray           aura5
# 23            black           aura6
# 24            black           aura6
# 25            black           aura6
# 26            black           aura6
# 27            black           aura6
# 28            black           aura6
# 29           orange           aura7
# 30           orange           aura7
# 31           orange           aura7
# 32           orange           aura7
# 33           orange           aura7
# 34           orange           aura7
# 35           orange           aura7
# 36           purple           aura8
# 37           purple           aura8
# 38           purple           aura8
# 39            brown           aura9
# 40            brown           aura9
# 41            brown           aura9
# 42            brown           aura9
# 43            brown           aura9
# 44            brown           aura9
# 45            brown           aura9
# 46            brown           aura9

# %% [markdown]
# DATA CLEANING

# %%
#now we proceed to identifying anormaies in our dataset 

""" we look out for duplicate records
missing values
formatting"""
# Out:
# ' we look out for duplicate records\nmissing values\nformatting'

# %%
Email_fact_data.drop_duplicates()
# Out:
#                From Name           From seniority       From Department  \
# Email id
# 1           Leona McAree                  C-level  Executive Management
# 2           Leona McAree                  C-level  Executive Management
# 3           Leona McAree                  C-level  Executive Management
# 4           Leona McAree                  C-level  Executive Management
# 5           Leona McAree                  C-level  Executive Management
# ...                  ...                      ...                   ...
# 1193      Emmey Matoshin  Middle level management                 Sales
# 1194      Emmey Matoshin  Middle level management                 Sales
# 1195      Emmey Matoshin  Middle level management                 Sales
# 1196      Emmey Matoshin  Middle level management                 Sales
# 1197      Emmey Matoshin  Middle level management                 Sales
#
#                      To Name             To seniority           To Department  \
# Email id
# 1         Elsinore Waterland  Middle level management         Human Resources
# 2         Elsinore Waterland  Middle level management         Human Resources
# 3         Elsinore Waterland  Middle level management         Human Resources
# 4         Elsinore Waterland  Middle level management         Human Resources
# 5         Elsinore Waterland  Middle level management         Human Resources
# ...                      ...                      ...                     ...
# 1193         Blithe Arnaudet  Middle level management  Finance and Accounting
# 1194         Blithe Arnaudet  Middle level management  Finance and Accounting
# 1195         Blithe Arnaudet  Middle level management  Finance and Accounting
# 1196         Blithe Arnaudet  Middle level management  Finance and Accounting
# 1197         Blithe Arnaudet  Middle level management  Finance and Accounting
#
#                      Email topic       Date Sentiment Is opened?   Device  \
# Email id
# 1             Operational Issues  3/14/2024   neutral     opened  desktop
# 2              HR related topics  3/22/2024  positive     opened   mobile
# 3             Meeting Scheduling  3/26/2024   neutral   unopened  desktop
# 4              HR related topics  3/11/2024   neutral     opened   mobile
# 5              HR related topics  3/11/2024  positive     opened   mobile
# ...                          ...        ...       ...        ...      ...
# 1193      Finance and Accounting  3/28/2024  positive     opened   mobile
# 1194      Finance and Accounting   3/7/2024  negative     opened  desktop
# 1195          Operational Issues  3/14/2024   neutral     opened  desktop
# 1196          Meeting Scheduling   3/8/2024  positive     opened  desktop
# 1197      Finance and Accounting  3/23/2024   neutral     opened   mobile
#
#          Within work hours Within workdays
# Email id
# 1                      yes             yes
# 2                       no             yes
# 3                      yes             yes
# 4                      yes             yes
# 5                      yes             yes
# ...                    ...             ...
# 1193                   yes             yes
# 1194                   yes             yes
# 1195                    no             yes
# 1196                   yes             yes
# 1197                    no              no
#
# [1121 rows x 13 columns]

# %%
#checking for nulls within our dataset
Email_fact_data[Email_fact_data.isnull() == True]

##Email_fact_data.isnull() == True
# Out:
#          From Name From seniority From Department To Name To seniority  \
# Email id
# 1              NaN            NaN             NaN     NaN          NaN
# 2              NaN            NaN             NaN     NaN          NaN
# 3              NaN            NaN             NaN     NaN          NaN
# 4              NaN            NaN             NaN     NaN          NaN
# 5              NaN            NaN             NaN     NaN          NaN
# ...            ...            ...             ...     ...          ...
# 1193           NaN            NaN             NaN     NaN          NaN
# 1194           NaN            NaN             NaN     NaN          NaN
# 1195           NaN            NaN             NaN     NaN          NaN
# 1196           NaN            NaN             NaN     NaN          NaN
# 1197           NaN            NaN             NaN     NaN          NaN
#
#          To Department Email topic Date Sentiment Is opened? Device  \
# Email id
# 1                  NaN         NaN  NaN       NaN        NaN    NaN
# 2                  NaN         NaN  NaN       NaN        NaN    NaN
# 3                  NaN         NaN  NaN       NaN        NaN    NaN
# 4                  NaN         NaN  NaN       NaN        NaN    NaN
# 5                  NaN         NaN  NaN       NaN        NaN    NaN
# ...                ...         ...  ...       ...        ...    ...
# 1193               NaN         NaN  NaN       NaN        NaN    NaN
# 1194               NaN         NaN  NaN       NaN        NaN    NaN
# 1195               NaN         NaN  NaN       NaN        NaN    NaN
# 1196               NaN         NaN  NaN       NaN        NaN    NaN
# 1197               NaN         NaN  NaN       NaN        NaN    NaN
#
#          Within work hours Within workdays
# Email id
# 1                      NaN             NaN
# 2                      NaN             NaN
# 3                      NaN             NaN
# 4                      NaN             NaN
# 5                      NaN             NaN
# ...                    ...             ...
# 1193                   NaN             NaN
# 1194                   NaN             NaN
# 1195                   NaN             NaN
# 1196                   NaN             NaN
# 1197                   NaN             NaN
#
# [1132 rows x 13 columns]

# %%
#resetting column names
Email_fact_data.reset_index(inplace= True)

# %%
Email_fact_data.columns
# Out:
# Index(['Email id', 'From Name', 'From seniority', 'From Department', 'To Name',
#        'To seniority', 'To Department', 'Email topic', 'Date', 'Sentiment',
#        'Is opened?', 'Device', 'Within work hours', 'Within workdays'],
#       dtype='object')

# %%
#we standardize our column names

New_columns = ['Email_id', 'Sender_Name', 'Sender_cadre', 'Sender_dept', 'Rec_name',
       'Rec_cadre', 'Rec_dept', 'Email_subject', 'Msg_Date', 'Sentiment',
       'Msg_status', 'Device', 'Within_work_hrs', 'Within_workdays']

Email_fact_data.columns = New_columns

# %%
#renaming single columns
Email_fact_data.rename(columns = {'Msg_status': 'Message_status'}, inplace= True)

# %%
Email_fact_data
# Out:
#       Email_id     Sender_Name             Sender_cadre           Sender_dept  \
# 0            1    Leona McAree                  C-level  Executive Management
# 1            2    Leona McAree                  C-level  Executive Management
# 2            3    Leona McAree                  C-level  Executive Management
# 3            4    Leona McAree                  C-level  Executive Management
# 4            5    Leona McAree                  C-level  Executive Management
# ...        ...             ...                      ...                   ...
# 1127      1193  Emmey Matoshin  Middle level management                 Sales
# 1128      1194  Emmey Matoshin  Middle level management                 Sales
# 1129      1195  Emmey Matoshin  Middle level management                 Sales
# 1130      1196  Emmey Matoshin  Middle level management                 Sales
# 1131      1197  Emmey Matoshin  Middle level management                 Sales
#
#                 Rec_name                Rec_cadre                Rec_dept  \
# 0     Elsinore Waterland  Middle level management         Human Resources
# 1     Elsinore Waterland  Middle level management         Human Resources
# 2     Elsinore Waterland  Middle level management         Human Resources
# 3     Elsinore Waterland  Middle level management         Human Resources
# 4     Elsinore Waterland  Middle level management         Human Resources
# ...                  ...                      ...                     ...
# 1127     Blithe Arnaudet  Middle level management  Finance and Accounting
# 1128     Blithe Arnaudet  Middle level management  Finance and Accounting
# 1129     Blithe Arnaudet  Middle level management  Finance and Accounting
# 1130     Blithe Arnaudet  Middle level management  Finance and Accounting
# 1131     Blithe Arnaudet  Middle level management  Finance and Accounting
#
#                Email_subject   Msg_Date Sentiment Message_status   Device  \
# 0         Operational Issues  3/14/2024   neutral         opened  desktop
# 1          HR related topics  3/22/2024  positive         opened   mobile
# 2         Meeting Scheduling  3/26/2024   neutral       unopened  desktop
# 3          HR related topics  3/11/2024   neutral         opened   mobile
# 4          HR related topics  3/11/2024  positive         opened   mobile
# ...                      ...        ...       ...            ...      ...
# 1127  Finance and Accounting  3/28/2024  positive         opened   mobile
# 1128  Finance and Accounting   3/7/2024  negative         opened  desktop
# 1129      Operational Issues  3/14/2024   neutral         opened  desktop
# 1130      Meeting Scheduling   3/8/2024  positive         opened  desktop
# 1131  Finance and Accounting  3/23/2024   neutral         opened   mobile
#
#      Within_work_hrs Within_workdays
# 0                yes             yes
# 1                 no             yes
# 2                yes             yes
# 3                yes             yes
# 4                yes             yes
# ...              ...             ...
# 1127             yes             yes
# 1128             yes             yes
# 1129              no             yes
# 1130             yes             yes
# 1131              no              no
#
# [1132 rows x 14 columns]

# %%
#now we fix the date column
Email_fact_data['Msg_Date'] = pd.to_datetime(Email_fact_data['Msg_Date'])
Email_fact_data
# Out:
#       Email_id     Sender_Name             Sender_cadre           Sender_dept  \
# 0            1    Leona McAree                  C-level  Executive Management
# 1            2    Leona McAree                  C-level  Executive Management
# 2            3    Leona McAree                  C-level  Executive Management
# 3            4    Leona McAree                  C-level  Executive Management
# 4            5    Leona McAree                  C-level  Executive Management
# ...        ...             ...                      ...                   ...
# 1127      1193  Emmey Matoshin  Middle level management                 Sales
# 1128      1194  Emmey Matoshin  Middle level management                 Sales
# 1129      1195  Emmey Matoshin  Middle level management                 Sales
# 1130      1196  Emmey Matoshin  Middle level management                 Sales
# 1131      1197  Emmey Matoshin  Middle level management                 Sales
#
#                 Rec_name                Rec_cadre                Rec_dept  \
# 0     Elsinore Waterland  Middle level management         Human Resources
# 1     Elsinore Waterland  Middle level management         Human Resources
# 2     Elsinore Waterland  Middle level management         Human Resources
# 3     Elsinore Waterland  Middle level management         Human Resources
# 4     Elsinore Waterland  Middle level management         Human Resources
# ...                  ...                      ...                     ...
# 1127     Blithe Arnaudet  Middle level management  Finance and Accounting
# 1128     Blithe Arnaudet  Middle level management  Finance and Accounting
# 1129     Blithe Arnaudet  Middle level management  Finance and Accounting
# 1130     Blithe Arnaudet  Middle level management  Finance and Accounting
# 1131     Blithe Arnaudet  Middle level management  Finance and Accounting
#
#                Email_subject   Msg_Date Sentiment Message_status   Device  \
# 0         Operational Issues 2024-03-14   neutral         opened  desktop
# 1          HR related topics 2024-03-22  positive         opened   mobile
# 2         Meeting Scheduling 2024-03-26   neutral       unopened  desktop
# 3          HR related topics 2024-03-11   neutral         opened   mobile
# 4          HR related topics 2024-03-11  positive         opened   mobile
# ...                      ...        ...       ...            ...      ...
# 1127  Finance and Accounting 2024-03-28  positive         opened   mobile
# 1128  Finance and Accounting 2024-03-07  negative         opened  desktop
# 1129      Operational Issues 2024-03-14   neutral         opened  desktop
# 1130      Meeting Scheduling 2024-03-08  positive         opened  desktop
# 1131  Finance and Accounting 2024-03-23   neutral         opened   mobile
#
#      Within_work_hrs Within_workdays
# 0                yes             yes
# 1                 no             yes
# 2                yes             yes
# 3                yes             yes
# 4                yes             yes
# ...              ...             ...
# 1127             yes             yes
# 1128             yes             yes
# 1129              no             yes
# 1130             yes             yes
# 1131              no              no
#
# [1132 rows x 14 columns]

# %%
#we move on to clean our second table

Email_dim.head()
# Out:
#                        Name            Department  \
# 0              Leona McAree  Executive Management
# 1  Constancia Di Bartolomeo  Executive Management
# 2         Corey Scandwright  Executive Management
# 3        Elsinore Waterland       Human Resources
# 4          Petronilla Mapes       Human Resources
#
#                                     email                Seniority  \
# 0              leona.mcaree@kochgroup.com                  C-level
# 1  constancia.di bartolomeo@kochgroup.com                  C-level
# 2         corey.scandwright@kochgroup.com                  C-level
# 3        elsinore.waterland@kochgroup.com  Middle level management
# 4          petronilla.mapes@kochgroup.com             Professional
#
#   Department color Department aura
# 0              red           aura1
# 1              red           aura1
# 2              red           aura1
# 3           yellow           aura2
# 4           yellow           aura2

# %%
Email_dim.columns
# Out:
# Index(['Name', 'Department', 'email', 'Seniority', 'Department color',
#        'Department aura'],
#       dtype='object')

# %%
Email_dim.rename(columns={'Department color': 'Dept_color'}, inplace = True)

# %%
Email_dim.rename(columns={'Department aura': 'Dept_aura'},inplace= True )

Email_dim.head()
# Out:
#                        Name            Department  \
# 0              Leona McAree  Executive Management
# 1  Constancia Di Bartolomeo  Executive Management
# 2         Corey Scandwright  Executive Management
# 3        Elsinore Waterland       Human Resources
# 4          Petronilla Mapes       Human Resources
#
#                                     email                Seniority Dept_color  \
# 0              leona.mcaree@kochgroup.com                  C-level        red
# 1  constancia.di bartolomeo@kochgroup.com                  C-level        red
# 2         corey.scandwright@kochgroup.com                  C-level        red
# 3        elsinore.waterland@kochgroup.com  Middle level management     yellow
# 4          petronilla.mapes@kochgroup.com             Professional     yellow
#
#   Dept_aura
# 0     aura1
# 1     aura1
# 2     aura1
# 3     aura2
# 4     aura2

# %% [markdown]
# EXPLORATORY DATA ANALYSIS
#
# 1. COMMUNICATION PATTERN AND EMAIL VOLUME

# %%
#now we start our analysis

#Email volumes and communication patterns

#total email sent

tot_emails = Email_fact_data['Email_id'].count()
tot_emails
#print('total emails for the month of March is:', tot_emails)
# Out:
# 1132

# %%
#email volume sent by dept
email_by_dept = Email_fact_data['Sender_dept'].value_counts().reset_index(name = "Total_out_going_mails").sort_values("Total_out_going_mails", ascending= False)
email_by_dept
# Out:
#                    Sender_dept  Total_out_going_mails
# 0         Executive Management                    287
# 1                    Marketing                    146
# 2          Product development                    133
# 3                        Sales                    128
# 4  Information Technology (IT)                    120
# 5                        Legal                    117
# 6             Customer Service                    105
# 7       Finance and Accounting                     57
# 8              Human Resources                     39

# %%
#email volume incoming/received by department

email_rec_by_dept = Email_fact_data['Rec_dept'].value_counts().reset_index(name = "Tot_incoming_mails").sort_values("Tot_incoming_mails", ascending= False)
email_rec_by_dept
# Out:
#                       Rec_dept  Tot_incoming_mails
# 0          Product development                 205
# 1                    Marketing                 164
# 2                        Sales                 160
# 3  Information Technology (IT)                 155
# 4                        Legal                 136
# 5             Customer Service                 116
# 6       Finance and Accounting                  90
# 7              Human Resources                  58
# 8         Executive Management                  48

# %%
#email volume sent by cadre

email_by_cadre = Email_fact_data[['Sender_cadre']].value_counts().reset_index(name = 'Sender_mail_count').sort_values('Sender_mail_count', ascending= False)
email_by_cadre
# Out:
#               Sender_cadre  Sender_mail_count
# 0             Professional                500
# 1  Middle level management                345
# 2                  C-level                287

# %%
#emails recieved by cadre
email_rec_by_cadre = Email_fact_data[['Rec_cadre']].value_counts().sort_values(ascending= False)
email_rec_by_cadre
# Out:
# Rec_cadre
# Professional               649
# Middle level management    435
# C-level                     48
# Name: count, dtype: int64

# %%
#we assign our dataset to a new variable

#email_fact = Email_fact_data

# %%
#total emails sent by days
#first we extract days from our date column

email_by_days = Email_fact_data['Msg_Date'].value_counts().reset_index(name='email_count').sort_values('email_count', ascending= False)
email_by_days
# Out:
#      Msg_Date  email_count
# 0  2024-03-14           77
# 1  2024-03-13           70
# 2  2024-03-15           66
# 3  2024-03-12           66
# 4  2024-03-29           62
# 5  2024-03-07           61
# 6  2024-03-26           53
# 7  2024-03-27           53
# 8  2024-03-05           52
# 9  2024-03-28           51
# 10 2024-03-06           51
# 11 2024-03-25           49
# 12 2024-03-18           49
# 13 2024-03-11           49
# 14 2024-03-08           47
# 15 2024-03-20           46
# 16 2024-03-21           41
# 17 2024-03-22           39
# 18 2024-03-19           34
# 19 2024-03-04           27
# 20 2024-03-01           23
# 21 2024-03-30           16
# 22 2024-03-23           11
# 23 2024-03-02            9
# 24 2024-03-31            9
# 25 2024-03-16            7
# 26 2024-03-24            7
# 27 2024-03-17            5
# 28 2024-03-03            2

# %%
pd.set_option('display.max_rows', 31 )

# %%
#now we shall expand our fact table to include the following columns
#this allows us get the weekly email volume
"""
day gives us the day number in the month
day_name = this gives us the name of the day in the week, 
week_no"""
#day
Email_fact_data['Day_of_mon'] = Email_fact_data['Msg_Date'].dt.day

#day_name

Email_fact_data['day_name'] = Email_fact_data['Msg_Date'].dt.day_name()
Email_fact_data
# Out:
#       Email_id     Sender_Name             Sender_cadre           Sender_dept  \
# 0            1    Leona McAree                  C-level  Executive Management
# 1            2    Leona McAree                  C-level  Executive Management
# 2            3    Leona McAree                  C-level  Executive Management
# 3            4    Leona McAree                  C-level  Executive Management
# 4            5    Leona McAree                  C-level  Executive Management
# ...        ...             ...                      ...                   ...
# 1127      1193  Emmey Matoshin  Middle level management                 Sales
# 1128      1194  Emmey Matoshin  Middle level management                 Sales
# 1129      1195  Emmey Matoshin  Middle level management                 Sales
# 1130      1196  Emmey Matoshin  Middle level management                 Sales
# 1131      1197  Emmey Matoshin  Middle level management                 Sales
#
#                 Rec_name                Rec_cadre                Rec_dept  \
# 0     Elsinore Waterland  Middle level management         Human Resources
# 1     Elsinore Waterland  Middle level management         Human Resources
# 2     Elsinore Waterland  Middle level management         Human Resources
# 3     Elsinore Waterland  Middle level management         Human Resources
# 4     Elsinore Waterland  Middle level management         Human Resources
# ...                  ...                      ...                     ...
# 1127     Blithe Arnaudet  Middle level management  Finance and Accounting
# 1128     Blithe Arnaudet  Middle level management  Finance and Accounting
# 1129     Blithe Arnaudet  Middle level management  Finance and Accounting
# 1130     Blithe Arnaudet  Middle level management  Finance and Accounting
# 1131     Blithe Arnaudet  Middle level management  Finance and Accounting
#
#                Email_subject   Msg_Date Sentiment Message_status   Device  \
# 0         Operational Issues 2024-03-14   neutral         opened  desktop
# 1          HR related topics 2024-03-22  positive         opened   mobile
# 2         Meeting Scheduling 2024-03-26   neutral       unopened  desktop
# 3          HR related topics 2024-03-11   neutral         opened   mobile
# 4          HR related topics 2024-03-11  positive         opened   mobile
# ...                      ...        ...       ...            ...      ...
# 1127  Finance and Accounting 2024-03-28  positive         opened   mobile
# 1128  Finance and Accounting 2024-03-07  negative         opened  desktop
# 1129      Operational Issues 2024-03-14   neutral         opened  desktop
# 1130      Meeting Scheduling 2024-03-08  positive         opened  desktop
# 1131  Finance and Accounting 2024-03-23   neutral         opened   mobile
#
#      Within_work_hrs Within_workdays  Day_of_mon  day_name
# 0                yes             yes          14  Thursday
# 1                 no             yes          22    Friday
# 2                yes             yes          26   Tuesday
# 3                yes             yes          11    Monday
# 4                yes             yes          11    Monday
# ...              ...             ...         ...       ...
# 1127             yes             yes          28  Thursday
# 1128             yes             yes           7  Thursday
# 1129              no             yes          14  Thursday
# 1130             yes             yes           8    Friday
# 1131              no              no          23  Saturday
#
# [1132 rows x 16 columns]

# %%
#next we shall create a custom funcdtion to enable us get the week no

#first we define our function
def week_of_month(dt):
    #next we extract the first day of the month
    first_day = dt.replace(day = 1)
    dom = dt.day
    adjusted_dom = first_day.weekday() + dom
    return  int(np.ceil(adjusted_dom/7.0))



#week_no
week_extract = Email_fact_data['Msg_Date'].apply(week_of_month)
Email_fact_data['Week_of_month'] = 'week' + ' ' + week_extract.astype(str)
Email_fact_data
# Out:
#       Email_id     Sender_Name             Sender_cadre           Sender_dept  \
# 0            1    Leona McAree                  C-level  Executive Management
# 1            2    Leona McAree                  C-level  Executive Management
# 2            3    Leona McAree                  C-level  Executive Management
# 3            4    Leona McAree                  C-level  Executive Management
# 4            5    Leona McAree                  C-level  Executive Management
# ...        ...             ...                      ...                   ...
# 1127      1193  Emmey Matoshin  Middle level management                 Sales
# 1128      1194  Emmey Matoshin  Middle level management                 Sales
# 1129      1195  Emmey Matoshin  Middle level management                 Sales
# 1130      1196  Emmey Matoshin  Middle level management                 Sales
# 1131      1197  Emmey Matoshin  Middle level management                 Sales
#
#                 Rec_name                Rec_cadre                Rec_dept  \
# 0     Elsinore Waterland  Middle level management         Human Resources
# 1     Elsinore Waterland  Middle level management         Human Resources
# 2     Elsinore Waterland  Middle level management         Human Resources
# 3     Elsinore Waterland  Middle level management         Human Resources
# 4     Elsinore Waterland  Middle level management         Human Resources
# ...                  ...                      ...                     ...
# 1127     Blithe Arnaudet  Middle level management  Finance and Accounting
# 1128     Blithe Arnaudet  Middle level management  Finance and Accounting
# 1129     Blithe Arnaudet  Middle level management  Finance and Accounting
# 1130     Blithe Arnaudet  Middle level management  Finance and Accounting
# 1131     Blithe Arnaudet  Middle level management  Finance and Accounting
#
#                Email_subject   Msg_Date Sentiment Message_status   Device  \
# 0         Operational Issues 2024-03-14   neutral         opened  desktop
# 1          HR related topics 2024-03-22  positive         opened   mobile
# 2         Meeting Scheduling 2024-03-26   neutral       unopened  desktop
# 3          HR related topics 2024-03-11   neutral         opened   mobile
# 4          HR related topics 2024-03-11  positive         opened   mobile
# ...                      ...        ...       ...            ...      ...
# 1127  Finance and Accounting 2024-03-28  positive         opened   mobile
# 1128  Finance and Accounting 2024-03-07  negative         opened  desktop
# 1129      Operational Issues 2024-03-14   neutral         opened  desktop
# 1130      Meeting Scheduling 2024-03-08  positive         opened  desktop
# 1131  Finance and Accounting 2024-03-23   neutral         opened   mobile
#
#      Within_work_hrs Within_workdays  Day_of_mon  day_name Week_of_month
# 0                yes             yes          14  Thursday        week 3
# 1                 no             yes          22    Friday        week 4
# 2                yes             yes          26   Tuesday        week 5
# 3                yes             yes          11    Monday        week 3
# 4                yes             yes          11    Monday        week 3
# ...              ...             ...         ...       ...           ...
# 1127             yes             yes          28  Thursday        week 5
# 1128             yes             yes           7  Thursday        week 2
# 1129              no             yes          14  Thursday        week 3
# 1130             yes             yes           8    Friday        week 2
# 1131              no              no          23  Saturday        week 4
#
# [1132 rows x 17 columns]

# %%
#now we shall look at the number of emails by days and week
email_days = Email_fact_data['day_name'].explode().value_counts().reset_index(name= 'email_count').sort_values('email_count',ascending = False)
email_days
# Out:
#     day_name  email_count
# 0     Friday          237
# 1   Thursday          230
# 2  Wednesday          220
# 3    Tuesday          205
# 4     Monday          174
# 5   Saturday           43
# 6     Sunday           23

# %%
email_by_dayys = Email_fact_data['day_name'].value_counts().reset_index(name= 'mail_count').sort_values('mail_count', ascending = False)
email_by_dayys
# Out:
#     day_name  mail_count
# 0     Friday         237
# 1   Thursday         230
# 2  Wednesday         220
# 3    Tuesday         205
# 4     Monday         174
# 5   Saturday          43
# 6     Sunday          23

# %%
#weekly emails sent
weekly_email = Email_fact_data['Week_of_month'].explode().value_counts().reset_index(name= 'email_vol').sort_values('email_vol', ascending = False)
weekly_email

#email_weekly = Email_fact_data['Week_of_month'].value_counts()
#email_weekly
# Out:
#   Week_of_month  email_vol
# 0        week 3        340
# 1        week 5        293
# 2        week 2        238
# 3        week 4        227
# 4        week 1         34

# %%
#weekly and daily email distribution
Email_fact_data.sort_index()
day_week = Email_fact_data.groupby(['Week_of_month', 'Day_of_mon' ,'day_name']).size().reset_index(name = 'daily_mails').sort_values(by = ['Week_of_month', 'daily_mails'], ascending= [True, False])
day_week
# Out:
#    Week_of_month  Day_of_mon   day_name  daily_mails
# 0         week 1           1     Friday           23
# 1         week 1           2   Saturday            9
# 2         week 1           3     Sunday            2
# 6         week 2           7   Thursday           61
# 4         week 2           5    Tuesday           52
# 5         week 2           6  Wednesday           51
# 7         week 2           8     Friday           47
# 3         week 2           4     Monday           27
# 11        week 3          14   Thursday           77
# 10        week 3          13  Wednesday           70
# 9         week 3          12    Tuesday           66
# 12        week 3          15     Friday           66
# 8         week 3          11     Monday           49
# 13        week 3          16   Saturday            7
# 14        week 3          17     Sunday            5
# 15        week 4          18     Monday           49
# 17        week 4          20  Wednesday           46
# 18        week 4          21   Thursday           41
# 19        week 4          22     Friday           39
# 16        week 4          19    Tuesday           34
# 20        week 4          23   Saturday           11
# 21        week 4          24     Sunday            7
# 26        week 5          29     Friday           62
# 23        week 5          26    Tuesday           53
# 24        week 5          27  Wednesday           53
# 25        week 5          28   Thursday           51
# 22        week 5          25     Monday           49
# 27        week 5          30   Saturday           16
# 28        week 5          31     Sunday            9

# %%
#email by sender_cadre

sender_cadre = Email_fact_data['Sender_cadre'].value_counts().reset_index(name= 'email_vol').sort_values('email_vol', ascending = False)
sender_cadre
# Out:
#               Sender_cadre  email_vol
# 0             Professional        500
# 1  Middle level management        345
# 2                  C-level        287

# %%
#email by rec_cadre 
rec_cadre = Email_fact_data['Rec_cadre'].value_counts().reset_index(name= 'email_vol').sort_values('email_vol', ascending = False)
rec_cadre
# Out:
#                  Rec_cadre  email_vol
# 0             Professional        649
# 1  Middle level management        435
# 2                  C-level         48

# %%
#volume of email exchnage between departments
email_exc_dept = Email_fact_data.groupby('Sender_dept')['Rec_dept'].value_counts().reset_index(name = "email_vol").sort_values('email_vol', ascending = False)
email_exc_dept

#pd.set_option('display.max_row', 39)
# Out:
#                     Sender_dept                     Rec_dept  email_vol
# 31          Product development          Product development        125
# 27                    Marketing                    Marketing        121
# 0              Customer Service             Customer Service         94
# 34                        Sales                        Sales         86
# 16  Information Technology (IT)  Information Technology (IT)         86
# ..                          ...                          ...        ...
# 22  Information Technology (IT)              Human Resources          2
# 21  Information Technology (IT)       Finance and Accounting          2
# 33          Product development  Information Technology (IT)          2
# 15              Human Resources  Information Technology (IT)          2
# 13       Finance and Accounting  Information Technology (IT)          2
#
# [39 rows x 3 columns]

# %%
#email exchange type
#here we come up with two categories for inter-dept and intra_dept mails that helps us
email_exc_dept['exc_type'] = ''

for i,  (Sender_dept, Rec_dept) in enumerate(zip(email_exc_dept['Sender_dept'], email_exc_dept['Rec_dept'])):
    if Sender_dept == Rec_dept:
        email_exc_dept.at[i,'exc_type'] = 'intra_mails'
    else:
        email_exc_dept.at[i,'exc_type'] = 'inter_mail'

# %%
#expanded email fact data

Email_fact_data['mail_exc_type'] = ''


for i, (Sender_dept, Rec_dept) in enumerate(zip(Email_fact_data['Sender_dept'],Email_fact_data['Rec_dept'])):
    if Sender_dept == Rec_dept:
        Email_fact_data.at[i, 'mail_exc_type'] = 'intra_mails'
    else:
        Email_fact_data.at[i, 'mail_exc_type'] = 'inter_mails'

# %%
Email_fact_data.head()
# Out:
#    Email_id   Sender_Name Sender_cadre           Sender_dept  \
# 0         1  Leona McAree      C-level  Executive Management
# 1         2  Leona McAree      C-level  Executive Management
# 2         3  Leona McAree      C-level  Executive Management
# 3         4  Leona McAree      C-level  Executive Management
# 4         5  Leona McAree      C-level  Executive Management
#
#              Rec_name                Rec_cadre         Rec_dept  \
# 0  Elsinore Waterland  Middle level management  Human Resources
# 1  Elsinore Waterland  Middle level management  Human Resources
# 2  Elsinore Waterland  Middle level management  Human Resources
# 3  Elsinore Waterland  Middle level management  Human Resources
# 4  Elsinore Waterland  Middle level management  Human Resources
#
#         Email_subject   Msg_Date Sentiment Message_status   Device  \
# 0  Operational Issues 2024-03-14   neutral         opened  desktop
# 1   HR related topics 2024-03-22  positive         opened   mobile
# 2  Meeting Scheduling 2024-03-26   neutral       unopened  desktop
# 3   HR related topics 2024-03-11   neutral         opened   mobile
# 4   HR related topics 2024-03-11  positive         opened   mobile
#
#   Within_work_hrs Within_workdays  Day_of_mon  day_name Week_of_month  \
# 0             yes             yes          14  Thursday        week 3
# 1              no             yes          22    Friday        week 4
# 2             yes             yes          26   Tuesday        week 5
# 3             yes             yes          11    Monday        week 3
# 4             yes             yes          11    Monday        week 3
#
#   mail_exc_type
# 0   inter_mails
# 1   inter_mails
# 2   inter_mails
# 3   inter_mails
# 4   inter_mails

# %%
Email_fact_data[['mail_exc_type']].value_counts(normalize= True).reset_index(name= 'vol_percent')
# Out:
#   mail_exc_type  vol_percent
# 0   intra_mails     0.637809
# 1   inter_mails     0.362191

# %%
#now we look at volume of email exchange between employees
pd.set_option('display.max_row', 300)
# 237         Rodrique Coulston          Minette Southard             7
# 238         Rodrique Coulston             Jorey Deguara             5
# 239         Rodrique Coulston            Lisette Loweth             4
# 240         Rodrique Coulston            Karine Barclay             3
# 241         Rodrique Coulston              Reina Trobey             1
# 242           Roger Tabbernor      Lazarus O'Halleghane            19
# 243           Roger Tabbernor              Traci Habbal             6
# 244           Roger Tabbernor           Dorie Parradine             1
# 245           Sumner Blakeway           Maurine Golding             3
# 246           Sumner Blakeway            Emmey Matoshin             1
# 247            Tades Querrard           Nelia Routledge             3
# 248            Tades Querrard             Faythe Vassel             2
# 249            Tades Querrard            Emmey Matoshin             1
# 250            Tades Querrard            Marilyn Seeman             1
# 251            Tades Querrard           Maurine Golding             1
# 252            Tades Querrard              Reina Trobey             1
# 253            Tamara Brewitt            Mata McGifford             4
# 254            Tamara Brewitt            Marilyn Seeman             1
# 255            Tamara Brewitt              Reina Trobey             1
# 256          Theressa Tuddall              Maggy Putson             5
# 257          Theressa Tuddall             Jorey Deguara             3
# 258              Traci Habbal            Emmey Matoshin            11
# 259              Traci Habbal          Petronille Jouen            10
# 260              Traci Habbal           Dorie Parradine             9
# 261              Traci Habbal            Karine Barclay             9
# 262              Traci Habbal           Roger Tabbernor             7
# 263              Traci Habbal      Lazarus O'Halleghane             6

# %%
#email volume by employees

email_by_emp = Email_fact_data['Sender_Name'].value_counts().reset_index(name = 'sent_mail_count').sort_values(by = 'sent_mail_count', ascending = False)
email_by_emp
# Out:
#                  Sender_Name  sent_mail_count
# 0               Leona McAree              143
# 1   Constancia Di Bartolomeo               99
# 2             Mata McGifford               62
# 3             Emmey Matoshin               60
# 4               Traci Habbal               52
# 5              Jorey Deguara               49
# 6          Corey Scandwright               45
# 7              Faythe Vassel               44
# 8             Jeannie Moggan               42
# 9             Marilyn Seeman               35
# 10             Abigael Alred               34
# 12           Maurine Golding               31
# 11      Lazarus O'Halleghane               31
# 13              Reina Trobey               30
# 14           Blithe Arnaudet               26
# 15           Roger Tabbernor               26
# 16   Constantino FitzGilbert               20
# 17        Elsinore Waterland               20
# 18         Rodrique Coulston               20
# 19              Maggy Putson               17
# 20            Karine Barclay               16
# 21           Chris Consadine               14
# 22        Mort De Benedictis               14
# 25            Madge Torrejon               13
# 23          Minette Southard               13
# 24          Petronilla Mapes               13
# 26                Oran Benge               12
# 27           Nelia Routledge               11
# 28          Petronille Jouen               11
# 29       Ferdinande Stickels               11
# 30            Anatole Hansie               11
# 31             Ozzy Jeffries               11
# 32           Dorie Parradine               10
# 33            Lisette Loweth               10
# 34            Tades Querrard                9
# 37           Angie Penticost                8
# 36          Theressa Tuddall                8
# 35           Grace Spracklin                8
# 38          Maribelle Oliver                6
# 39            Tamara Brewitt                6
# 40               Morly Finey                6
# 41                Lynett Amy                6
# 42            Elbertine Dowe                6
# 43             Barry Goundsy                4
# 44           Sumner Blakeway                4
# 45          Edithe Cinnamond                3
# 46             Katina Darter                2

# %%
email_rec_emp = Email_fact_data['Rec_name'].value_counts().reset_index(name = 'sent_mail_count').sort_values(by = 'sent_mail_count', ascending = False)
email_rec_emp
# Out:
#                     Rec_name  sent_mail_count
# 0              Jorey Deguara              104
# 1             Jeannie Moggan               64
# 2               Traci Habbal               62
# 3             Emmey Matoshin               54
# 4            Blithe Arnaudet               54
# 5              Abigael Alred               53
# 6               Reina Trobey               40
# 7              Faythe Vassel               40
# 8            Maurine Golding               32
# 9             Marilyn Seeman               30
# 10  Constancia Di Bartolomeo               27
# 11      Lazarus O'Halleghane               27
# 12           Roger Tabbernor               26
# 13          Edithe Cinnamond               25
# 14         Rodrique Coulston               23
# 15        Elsinore Waterland               23
# 16            Mata McGifford               21
# 17            Elbertine Dowe               21
# 18           Grace Spracklin               20
# 19          Petronille Jouen               19
# 20            Tamara Brewitt               19
# 21             Ozzy Jeffries               19
# 22            Karine Barclay               18
# 24       Ferdinande Stickels               17
# 23   Constantino FitzGilbert               17
# 25           Nelia Routledge               16
# 27            Tades Querrard               15
# 28                Lynett Amy               15
# 29        Mort De Benedictis               15
# 30          Minette Southard               15
# 31            Lisette Loweth               15
# 26           Chris Consadine               15
# 32          Maribelle Oliver               14
# 33           Angie Penticost               14
# 34          Petronilla Mapes               14
# 35              Maggy Putson               13
# 39                Oran Benge               12
# 40            Anatole Hansie               12
# 36           Dorie Parradine               12
# 38          Theressa Tuddall               12
# 37         Corey Scandwright               12
# 41             Barry Goundsy               11
# 42           Sumner Blakeway               11
# 43              Leona McAree                9
# 44             Katina Darter                9
# 45               Morly Finey                8
# 46            Madge Torrejon                8

# %%
#sent and rec volume by dept and name

vol = Email_fact_data.groupby(['Sender_dept', 'Sender_Name'])['Sender_Name'].value_counts().reset_index(name = 'mail_counts').sort_values(by= ['Sender_dept', 'mail_counts'], ascending= [True, False])
vol
#pd.set_option('display.max_row', 50)
# Out:
#                     Sender_dept               Sender_Name  mail_counts
# 3              Customer Service            Mata McGifford           62
# 5              Customer Service        Mort De Benedictis           14
# 0              Customer Service           Angie Penticost            8
# 2              Customer Service          Maribelle Oliver            6
# 4              Customer Service               Morly Finey            6
# 6              Customer Service            Tamara Brewitt            6
# 1              Customer Service          Edithe Cinnamond            3
# 9          Executive Management              Leona McAree          143
# 7          Executive Management  Constancia Di Bartolomeo           99
# 8          Executive Management         Corey Scandwright           45
# 10       Finance and Accounting           Blithe Arnaudet           26
# 11       Finance and Accounting   Constantino FitzGilbert           20
# 12       Finance and Accounting             Ozzy Jeffries           11
# 14              Human Resources        Elsinore Waterland           20
# 15              Human Resources          Petronilla Mapes           13
# 13              Human Resources            Elbertine Dowe            6
# 20  Information Technology (IT)            Marilyn Seeman           35
# 16  Information Technology (IT)             Abigael Alred           34
# 21  Information Technology (IT)              Reina Trobey           30
# 19  Information Technology (IT)            Madge Torrejon           13
# 18  Information Technology (IT)                Lynett Amy            6
# 17  Information Technology (IT)             Katina Darter            2
# 22                        Legal             Faythe Vassel           44
# 23                        Legal            Jeannie Moggan           42
# 24                        Legal           Maurine Golding           31
# 30                    Marketing              Traci Habbal           52
# 27                    Marketing      Lazarus O'Halleghane           31
# 29                    Marketing           Roger Tabbernor           26
# 26                    Marketing            Karine Barclay           16
# 28                    Marketing          Petronille Jouen           11
# 25                    Marketing           Dorie Parradine           10
# 32          Product development             Jorey Deguara           49
# 37          Product development         Rodrique Coulston           20
# 34          Product development              Maggy Putson           17
# 35          Product development          Minette Southard           13
# 36          Product development                Oran Benge           12
# 33          Product development            Lisette Loweth           10
# 38          Product development          Theressa Tuddall            8
# 31          Product development             Barry Goundsy            4
# 41                        Sales            Emmey Matoshin           60
# 40                        Sales           Chris Consadine           14
# 39                        Sales            Anatole Hansie           11
# 42                        Sales       Ferdinande Stickels           11
# 44                        Sales           Nelia Routledge           11
# 46                        Sales            Tades Querrard            9
# 43                        Sales           Grace Spracklin            8
# 45                        Sales           Sumner Blakeway            4

# %%
#to find out the personel who sent the heighest number of mail for each week

max_mail_sender_weekly = Email_fact_data.groupby('week_of_month')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 3
#       1 #to find out the personel who sent the heighest number of mail for each week
# ----> 3 max_mail_sender_weekly = Email_fact_data.groupby('week_of_month')
#
# File c:\Users\Djibril-PC\Documents\Projects\Analytics_projects\my_projects\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# File c:\Users\Djibril-PC\Documents\Projects\Analytics_projects\my_projects\Lib\site-packages\pandas\core\groupby\groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File c:\Users\Djibril-PC\Documents\Projects\Analytics_projects\my_projects\Lib\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'week_of_month'

# %%
vol = Email_fact_data.groupby(['Rec_dept', 'Rec_name'])['Rec_name'].value_counts().reset_index(name = 'mail_counts').sort_values(by= ['Rec_dept', 'mail_counts'], ascending= [True, False])
vol
#pd.set_option('display.max_row', 50)
# Out:
#                        Rec_dept                  Rec_name  mail_counts
# 1              Customer Service          Edithe Cinnamond           25
# 3              Customer Service            Mata McGifford           21
# 6              Customer Service            Tamara Brewitt           19
# 5              Customer Service        Mort De Benedictis           15
# 0              Customer Service           Angie Penticost           14
# 2              Customer Service          Maribelle Oliver           14
# 4              Customer Service               Morly Finey            8
# 7          Executive Management  Constancia Di Bartolomeo           27
# 8          Executive Management         Corey Scandwright           12
# 9          Executive Management              Leona McAree            9
# 10       Finance and Accounting           Blithe Arnaudet           54
# 12       Finance and Accounting             Ozzy Jeffries           19
# 11       Finance and Accounting   Constantino FitzGilbert           17
# 14              Human Resources        Elsinore Waterland           23
# 13              Human Resources            Elbertine Dowe           21
# 15              Human Resources          Petronilla Mapes           14
# 16  Information Technology (IT)             Abigael Alred           53
# 21  Information Technology (IT)              Reina Trobey           40
# 20  Information Technology (IT)            Marilyn Seeman           30
# 18  Information Technology (IT)                Lynett Amy           15
# 17  Information Technology (IT)             Katina Darter            9
# 19  Information Technology (IT)            Madge Torrejon            8
# 23                        Legal            Jeannie Moggan           64
# 22                        Legal             Faythe Vassel           40
# 24                        Legal           Maurine Golding           32
# 30                    Marketing              Traci Habbal           62
# 27                    Marketing      Lazarus O'Halleghane           27
# 29                    Marketing           Roger Tabbernor           26
# 28                    Marketing          Petronille Jouen           19
# 26                    Marketing            Karine Barclay           18
# 25                    Marketing           Dorie Parradine           12
# 32          Product development             Jorey Deguara          104
# 37          Product development         Rodrique Coulston           23
# 33          Product development            Lisette Loweth           15
# 35          Product development          Minette Southard           15
# 34          Product development              Maggy Putson           13
# 36          Product development                Oran Benge           12
# 38          Product development          Theressa Tuddall           12
# 31          Product development             Barry Goundsy           11
# 41                        Sales            Emmey Matoshin           54
# 43                        Sales           Grace Spracklin           20
# 42                        Sales       Ferdinande Stickels           17
# 44                        Sales           Nelia Routledge           16
# 40                        Sales           Chris Consadine           15
# 46                        Sales            Tades Querrard           15
# 39                        Sales            Anatole Hansie           12
# 45                        Sales           Sumner Blakeway           11

# %%
mail_by_dev = Email_fact_data['Device'].value_counts(normalize= True)
mail_by_dev
# Out:
# Device
# desktop    0.759717
# mobile     0.240283
# Name: proportion, dtype: float64

# %%
mail_by_sent = Email_fact_data['Sentiment'].value_counts()
mail_by_sent
# Out:
# Sentiment
# neutral     660
# positive    353
# negative    119
# Name: count, dtype: int64

# %%
mail_stat_by_sent = Email_fact_data.groupby('Sentiment')['Msg_status'].value_counts().reset_index(name = 'counts')
mail_stat_by_sent
# Out:
#   Sentiment Msg_status  counts
# 0  negative     opened     109
# 1  negative   unopened      10
# 2   neutral     opened     595
# 3   neutral   unopened      65
# 4  positive     opened     330
# 5  positive   unopened      23

# %%
#email volume by work hours and work days


work_hours_mail = Email_fact_data['Within_work_hrs'].value_counts(normalize = True).reset_index(name= 'percent')
work_hours_mail
# Out:
#   Within_work_hrs   percent
# 0             yes  0.805654
# 1              no  0.194346

# %%
work_day_mail = Email_fact_data['Within_workdays'].value_counts(normalize = True).reset_index(name= 'percent')
work_day_mail
# Out:
#   Within_workdays   percent
# 0             yes  0.941696
# 1              no  0.058304

# %% [markdown]
# TREND ANALYSIS FOR EMAIL VOLUME AND COMMUNICATIO PATTERN
#
#
# Here we shall look into our dataset to reveal the following:
#
# weekly
# What department sent the max number of emails on a weekly basis,
# What department recieved the max number of emails on a weekly basis,
# employee with highest number of sent mails for every week,
# employee with highest number of recieved mails for each week,
# most discussed topic for each week,
# departments with most communication for each week,
# employee with most communication for each week,
# percentage of exchange type for each week,
#
# daily
# What department sent the max number of emails on a day basis,
# What department recieved the max number of emails on a daily basis,
# employee with highest number of sent mails for every day,
# employee with highest number of recieved mails for each day,
# most discussed topic for each day,
# departments with most communication for each day,
# employee with most communication for each day,
# percentage of exchange type for wach day,

# %%
weekly_email_cummax = Email_fact_data.groupby('Week_of_month')['Sender_dept'].value_counts().reset_index(name= 'email_vol')
weekly_email_cummax
# Out:
#    Week_of_month                  Sender_dept  email_vol
# 0         week 1         Executive Management          7
# 1         week 1          Product development          7
# 2         week 1                        Legal          5
# 3         week 1                    Marketing          5
# 4         week 1  Information Technology (IT)          3
# ..           ...                          ...        ...
# 39        week 5          Product development         34
# 40        week 5  Information Technology (IT)         32
# 41        week 5             Customer Service         28
# 42        week 5              Human Resources          9
# 43        week 5       Finance and Accounting          7
#
# [44 rows x 3 columns]

# %%
#this syntax yielded error:
max_mail_by_week_dept = pd.DataFrame(columns=['Week_of_month', 'Sender_dept', 'email_vol'])

for i, (Week_of_month, Sender_dept, email_vol) in enumerate(zip([weekly_email_cummax['Week_of_month'], weekly_email_cummax['Sender_dept'], weekly_email_cummax['email_vol']])):
    if weekly_email_cummax['Week_of_month','email_vol'] == weekly_email_cummax.groupby(['Week_of_month'])['email_vol'].max():
      max_mail_by_week_dept.at[i, [Week_of_month, Sender_dept, email_vol]]  = weekly_email_cummax.groupby(['Week_of_month'])['email_vol'].max()
    else:
       pass
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 3
#       1 max_mail_by_week_dept = pd.DataFrame(columns=['Week_of_month', 'Sender_dept', 'email_vol'])
# ----> 3 for i, (Week_of_month, Sender_dept, email_vol) in enumerate(zip([weekly_email_cummax['Week_of_month'], weekly_email_cummax['Sender_dept'], weekly_email_cummax['email_vol']])):
#       4     if weekly_email_cummax['Week_of_month','email_vol'] == weekly_email_cummax.groupby(['Week_of_month'])['email_vol'].max():
#       5       max_mail_by_week_dept.at[i, [Week_of_month, Sender_dept, email_vol]]  = weekly_email_cummax.groupby(['Week_of_month'])['email_vol'].max()
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %%
max_mail_by_week_dept = pd.DataFrame(columns=['Week_of_month', 'Sender_dept', 'email_vol'])

weekly_max = weekly_email_cummax.groupby(['Week_of_month'])['email_vol'].idxmax()
weekly_max

max_mail_by_week_dept = weekly_email_cummax.loc[weekly_max].reset_index(drop=True)
max_mail_by_week_dept
# Out:
#   Week_of_month           Sender_dept  email_vol
# 0        week 1  Executive Management          7
# 1        week 2  Executive Management         65
# 2        week 3  Executive Management        100
# 3        week 4  Executive Management         50
# 4        week 5  Executive Management         65
